# %%
# !pip install transformers datasets rouge-score

import torch
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
import pandas as pd
from datasets import Dataset, DatasetDict
from transformers import MT5ForConditionalGeneration, MT5Tokenizer
from rouge_score import rouge_scorer
import numpy as np
import os
from tqdm import tqdm
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (4.0.0)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.12/dist-packages (0.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2026.1.4)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->rouge-score) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->rouge-score) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.22.0)

# %%
df = pd.read_parquet("Khmer_Data.parquet")
df = df.sample(n=10000, random_state=42)  # subset 3000 samples
dataset = Dataset.from_pandas(df)

# %%
# Step 2: Train / Validation / Test split
# ------------------------------
train_test = dataset.train_test_split(test_size=0.2, seed=42)
val_test = train_test['test'].train_test_split(test_size=0.5, seed=42)

train_data = train_test['train']
val_data   = val_test['train']
test_data  = val_test['test']

print("Train:", len(train_data), "Val:", len(val_data), "Test:", len(test_data))
# Out:
# Train: 8000 Val: 1000 Test: 1000

# %%
# Step 3: Load mT5 model & tokenizer
# ------------------------------
model_name = "google/mt5-small"  # small → CPU-friendly
tokenizer = MT5Tokenizer.from_pretrained(model_name)
model = MT5ForConditionalGeneration.from_pretrained(model_name)
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'T5Tokenizer'.
# The class this function is called from is 'MT5Tokenizer'.

# %%
# Step 4: Preprocessing
# ------------------------------
max_input_len = 512
max_output_len = 128

def preprocess(batch):
    inputs = tokenizer(batch['full_article'], truncation=True, padding='max_length', max_length=max_input_len)
    labels = tokenizer(batch['summary'], truncation=True, padding='max_length', max_length=max_output_len)
    batch['input_ids'] = inputs['input_ids']
    batch['attention_mask'] = inputs['attention_mask']
    batch['labels'] = labels['input_ids']
    return batch

train_data = train_data.map(preprocess)
val_data = val_data.map(preprocess)
test_data = test_data.map(preprocess)
# Out:
# Map:   0%|          | 0/8000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
# Step 5: Collate function for DataLoader
# ------------------------------
def batch_pad(batch):
    input_ids = pad_sequence([torch.tensor(x['input_ids']) for x in batch], batch_first=True, padding_value=tokenizer.pad_token_id)
    attention_mask = pad_sequence([torch.tensor(x['attention_mask']) for x in batch], batch_first=True, padding_value=0)
    labels = pad_sequence([torch.tensor(x['labels']) for x in batch], batch_first=True, padding_value=-100)
    return {
        "input_ids": input_ids,
        "attention_mask": attention_mask,
        "labels": labels
    }

train_loader = DataLoader(train_data, batch_size=4, shuffle=True, collate_fn=batch_pad)
val_loader   = DataLoader(val_data, batch_size=4, collate_fn=batch_pad)

# %%
# Step 6: Training setup
# ------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-5)

num_epochs = 15
patience = 3
best_val_loss = float('inf')
epochs_no_improve = 0

MODEL_DIR = "/content/drive/MyDrive/mt5_khmer_model"
os.makedirs(MODEL_DIR, exist_ok=True)

# ROUGE scorer
scorer = rouge_scorer.RougeScorer(['rouge1','rouge2','rougeL'], use_stemmer=False)

# %%
# Step 7: Training loop with Early Stopping
# ------------------------------
for epoch in range(num_epochs):
    model.train()
    running_loss = 0
    for batch in tqdm(train_loader, desc=f"Epoch {epoch+1}"):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_train_loss = running_loss / len(train_loader)

    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
            val_loss += outputs.loss.item()
    avg_val_loss = val_loss / len(val_loader)

    print(f"Epoch {epoch+1}/{num_epochs} -> Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

    # Early Stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        epochs_no_improve = 0
        # Save best model
        model.save_pretrained(MODEL_DIR)
        tokenizer.save_pretrained(MODEL_DIR)
        print("Validation improved. Model saved.")
    else:
        epochs_no_improve += 1
        print(f"No improvement for {epochs_no_improve} epoch(s).")
        if epochs_no_improve >= patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1: 100%|██████████| 2000/2000 [14:17<00:00,  2.33it/s]
# Epoch 1/15 -> Train Loss: 10.9678, Val Loss: 4.7182
# Validation improved. Model saved.
# Epoch 2: 100%|██████████| 2000/2000 [14:12<00:00,  2.35it/s]
# Epoch 2/15 -> Train Loss: 4.5779, Val Loss: 2.6816
# Validation improved. Model saved.
# Epoch 3: 100%|██████████| 2000/2000 [14:13<00:00,  2.34it/s]
# Epoch 3/15 -> Train Loss: 3.4007, Val Loss: 2.0188
# Validation improved. Model saved.
# Epoch 4: 100%|██████████| 2000/2000 [14:12<00:00,  2.35it/s]
# Epoch 4/15 -> Train Loss: 2.7243, Val Loss: 1.8169
# Validation improved. Model saved.
# Epoch 5: 100%|██████████| 2000/2000 [14:12<00:00,  2.35it/s]
# Epoch 5/15 -> Train Loss: 2.4177, Val Loss: 1.7318
# Validation improved. Model saved.
# Epoch 6: 100%|██████████| 2000/2000 [14:12<00:00,  2.35it/s]
# Epoch 6/15 -> Train Loss: 2.2291, Val Loss: 1.6906
# Validation improved. Model saved.
# Epoch 7: 100%|██████████| 2000/2000 [14:13<00:00,  2.34it/s]
# Epoch 7/15 -> Train Loss: 2.0948, Val Loss: 1.6578
# Validation improved. Model saved.
# Epoch 8: 100%|██████████| 2000/2000 [14:11<00:00,  2.35it/s]
# Epoch 8/15 -> Train Loss: 1.9991, Val Loss: 1.6304
# Validation improved. Model saved.
# Epoch 9: 100%|██████████| 2000/2000 [14:12<00:00,  2.35it/s]
# Epoch 9/15 -> Train Loss: 1.9343, Val Loss: 1.6156
# Validation improved. Model saved.
# Epoch 10: 100%|██████████| 2000/2000 [14:13<00:00,  2.34it/s]
# Epoch 10/15 -> Train Loss: 1.8781, Val Loss: 1.5860
# Validation improved. Model saved.
# Epoch 11: 100%|██████████| 2000/2000 [14:12<00:00,  2.35it/s]
# Epoch 11/15 -> Train Loss: 1.8327, Val Loss: 1.5690
# Validation improved. Model saved.
# Epoch 12: 100%|██████████| 2000/2000 [14:13<00:00,  2.34it/s]
# Epoch 12/15 -> Train Loss: 1.7893, Val Loss: 1.5412
# Validation improved. Model saved.
# Epoch 13: 100%|██████████| 2000/2000 [14:13<00:00,  2.34it/s]
# Epoch 13/15 -> Train Loss: 1.7517, Val Loss: 1.5293
# Validation improved. Model saved.
# Epoch 14: 100%|██████████| 2000/2000 [14:13<00:00,  2.34it/s]
# Epoch 14/15 -> Train Loss: 1.7167, Val Loss: 1.5111
# Validation improved. Model saved.
# Epoch 15: 100%|██████████| 2000/2000 [14:13<00:00,  2.34it/s]
# Epoch 15/15 -> Train Loss: 1.6820, Val Loss: 1.5100
# Validation improved. Model saved.

# %%
# Step 8: Evaluate first 10 validation articles
# ------------------------------
model.eval()
test_samples = val_data.select(range(20))
test_texts = [x['full_article'] for x in test_samples]
test_refs = [x['summary'] for x in test_samples]

inputs = tokenizer(test_texts, return_tensors="pt", truncation=True, padding=True, max_length=max_input_len).to(device)
with torch.no_grad():
    generated_ids = model.generate(**inputs, max_length=max_output_len, num_beams=4, early_stopping=True)

pred_texts = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)

# Print full article + reference + prediction + ROUGE
for i, (article, ref, pred) in enumerate(zip(test_texts, test_refs, pred_texts)):
    score = scorer.score(ref, pred)
    print(f"\n--- Article {i+1} ---")
    print("Full Article:\n", article)
    print("\nReference Summary:\n", ref)
    print("\nPredicted Summary:\n", pred)
    print("ROUGE-1:", round(score['rouge1'].fmeasure,4))
    print("ROUGE-2:", round(score['rouge2'].fmeasure,4))
    print("ROUGE-L:", round(score['rougeL'].fmeasure,4))
    print("-"*100)
# Out:
# --- Article 1 ---
# Full Article:
#  Sid Ahmed Ghlam អាយុ២៤ឆ្នាំ ជា​និស្សិត​រៀន​ផ្នែក​អេឡិចត្រូនិក នៅ​បារាំង ឧស្សាហ៍​ឡើង​ចុះ​ប្រទេស​បារាំង ព្រោះ​មានគ្រួសារ​រស់នៅ​ទីនោះ។ ជនសង្ស័យ​រូបនេះ​ស្គាល់​មនុស្សម្នា​ក់នៅ​ស៊ី​រី ដែល​បាន​សុំ​គេ​អោយ​វាយប្រហារ​វិហារ​គ្រិស្តសាសនា​មួ​ួ​យ រឺក៏​ពីរ​កន្លែង ក្នុង​ទីក្រុង​ប៉ារីស។ ការចាប់ខ្លួន​Sid Ahmed Ghlamមិនបាន​កើតឡើង​ដោយ​ព្រាងទុក​មុន​ឡើយ។ កាលពី​ព្រឹក​ថ្ងៃអាទិត្យ ជនសង្ស័យ​រូបនេះ​បាន​ទូរស័ព្ទ​ទៅ ក្រុម​SAMU ប្រាប់ថា ខ្លួន​របួស​ដោយ​គ្រាប់កាំភ្លើង ក្នុង​ហេតុការណ៍​លួច​មួយ នៅក្នុង​សង្កា​ត់ទី១៣ ក្នុង​ក្រុងប៉ារីស។ ក្រុម​SAMU បាន​រាយការណ៍​ទៅ​ប៉ូលិស។ ប៉ូលិស​ក៏បាន​រកឃើញ​អាវុធ​ជាច្រើន និង​អាវ​ការពារ​គ្រាប់ នៅក្នុង​រថយន្ត​របស់​ជនសង្ស័យ។ ក្រុម​អង្កេត​កំពុង​ស៊ើប​ថា តើ​Sid Ahmed Ghlam បាន​អាវុធ​ទាំងនេះ​មកពីណា។ នៅផ្ទះ​របស់​Sid Ahmed Ghlam ប៉ូលិស​បាន​រកឃើញ​ឯកសារ​ជាច្រើន ស្តីពី​ក្រុម​អាល់​កៃ​ដា និង​ក្រុម​ជី​ហាត​រដ្ឋ​អ៊ីស្លាម។ ប៉ូលិស​បារាំង​ក៏បាន​ចាប់ខ្លួន​ស្ត្រី​សង្ស័យ​ម្នាក់​ដែល​ធ្លាប់​ស្គាល់​និស្សិត​រូបនេះ​ដែរ។ ផ្នែក​ចារកិច្ច​បារាំង​ធ្លាប់បាន​កត់សំគាល់​ជនល្មើស​រួច​ម្តង​ហើយ ដោយសារ​គេ​ធ្លាប់​ចង់ទៅ​ស៊ី​រី។ បារាំង​បាន​តាមឃ្លាំមើល​ជនសង្ស័យ​រូបនេះ​ជាប្រចាំ។ កាលពី​ខែកុម្ភៈ ជនសង្ស័យ​បាន​ចាកចេញ​ទៅ​តួ​ក​គី​អស់​មួយ​សប្តាហ៍។ ដោយឡែក Sid Ahmed Ghlam ក៏ត្រូវ​ប៉ូលិស​សង្ស័យថា​បានសម្លាប់​គ្រូ​កីឡា​ស្រី​ម្នាក់ កាលពី​ថ្ងៃអាទិត្យ​ដដែល នៅ​សង្កា​ត់ទី១៣ក្រុងប៉ារីស​ដែរ ព្រោះ​ប៉ូលិស​បាន​រកឃើញ​DNAរបស់​ជនសង្ស័យ នៅលើ​ហ្វ្រាំងដៃ​រថយន្ត​របស់​ជន​រងគ្រោះ។ គ្រូ​ស្រី​រូប​នោះបាន​ស្លាប់​ដោយ​គ្រាប់កាំភ្លើង ក្នុង​រថយន្ត​របស់គាត់។ អាជ្ញាធរ​សង្ស័យថា និស្សិត​អាល់​ហ្សេ​រី​ប្រហែលជា​កំពុងតែ​ធ្វើ​ភេរវកម្ម​នៅ​វិហារ នៅ​ម្តុំ​សង្កា​ត់ទី១។ ជនល្មើស​ប្រហែល​បាន​ប្លន់​យក​រថយន្ត​របស់​គ្រូ​ស្រី​នោះ​ទៅប្រើ​ប្រាស់។ ជនល្មើស​ក៏​ប្រហែល​របួស​ដោយ​កាំភ្លើង​របស់​ខ្លួនឯង​ដែរ ក្នុងពេល​ប្រទាញប្រទង់​គ្នា​ជាមួយ​ជនរងគ្រោះ។ គម្រោង​ភេរវកម្ម​ប្រឆាំង​វិហារ​ដែល​ត្រូវ​ប៉ូលិស​ទប់ស្កាត់បាន​មុននេះ បានធ្វើអោយ​គ្រិស្ត​សាសនិកជន​បារាំង​មានការ​ព្រួយបារម្ភ​ខ្លាំង។ នាយករដ្ឋមន្ត្រី​បារាំង​ម៉ា​នុយ​អែល វ៉ាល់ បាន​លើកឡើងថា ការប៉ុនប៉ង​វាយប្រហារ​វិហារ​គ្រិស្តសាសនា គឺជា​ការវាយប្រហារ​និមិត្តរូប​ប្រទេស​បារាំង។ ដើមឆ្នាំ២០១៥នេះ បារាំង​ធ្លាប់​រងគ្រោះ​ដោយ​ការវាយប្រហារ​ភេរវកម្ម​ប្រឆាំង​កាសែត​ស្ហា​លី​អេប​ដូ សម្លាប់​មនុស្ស១៧នាក់ ធ្វើអោយ​មនុស្ស​គ្រប់ទិសទី​ថ្កោលទោស​អំពើ​ភេរវកម្ម​៕‏ ដោយ​បង សូលី​ណា អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  កាលពី​ថ្ងៃអាទិត្យ ប៉ូលិស​បារាំង​បាន​ចាប់ខ្លួន​និស្សិត​ជនជាតិ​អាល់​ហ្សេ​រី​ម្នាក់ ដែលមាន​គម្រោង​ធ្វើ​ភេរវកម្ម​ប្រឆាំង​វិហារ​គ្រិស្តសាសនា​ក្នុង​ទីក្រុង​ប៉ារីស។ ជនសង្ស័យ​មាន​អាយុ២៤ឆ្នាំ អាចជា​ឃាតករ​សម្លាប់​ស្ត្រី​ជា​គ្រូ​កីឡា​ម្នាក់ នៅក្នុង​ទីក្រុង​ប៉ារីស ក្នុង​ថ្ងៃអាទិត្យ​ដដែល​ផងដែរ។ ហេតុការណ៍​នេះ​កើតឡើង​មិន​ដល់៤ខែ​ទេ ក្រោយ​រដ្ឋធានី​ប្រទេស​បារាំង​រង​ការវាយប្រហារ​ភេរវកម្ម នៅ​ដើមខែ​មករា។
#
# Predicted Summary:
#  ប៉ូលិស បារាំង បាន ចាប់ខ្លួន ស្ត្រី សង្ស័យ ម្នាក់ ដែល ធ្លាប់ ស្គាល់ និស្សិត អាល់ ហ្សេ រី នៅ ថ្ងៃអាទិត្យ ដដែល នៅ សង្កា ត់ទី១៣ ក្នុង ក្រុងប៉ារីស។ ប៉ូលិស បារាំង បាន ចាប់ខ្លួន ស្ត្រី សង្ស័យ ម្នាក់ ដែល ធ្លាប់ ស្គាល់ និស្សិត អាល់ កៃ ដា និង ក្រុម ជី ហាត រដ្ឋ អ៊ីស្លាម។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 2 ---
# Full Article:
#  ក្នុងចំណោមបំណុលឯកជនសរុបទាំង ៥៧,៦ពាន់ដុល្លារ នៅក្នុងប្រព័ន្ធធនាគារកម្ពុជានេះ គឺមាន ៥១,៨ពាន់លានដុល្លារ នៅគ្រឹះស្ថានធនាគារ កើន១៨,២ភាគរយ។ ក៏ប៉ុន្តែទំហំបំណុលរបស់ពលរដ្ឋ នៅក្នុងវិស័យមីក្រូហិរញ្ញវត្ថុ បានធា្លក់ចុះរហូតដល់៤២,៦ភាគរយ ដែលមានទំហំទឹកប្រាក់ត្រឹម៥,៤ពាន់លានដុល្លារប៉ុណ្ណោះ ធៀបនឹងឆ្នាំ២០២២។ របាយណ៍ពីធនាគារជាតិ​ បានបង្ហាញថា ការកើនឡើងនៃបំណុលឯកជននេះ ដោយសារការងើបឡើងវិញនៃសកម្មភាពសេដ្ឋកិច្ច និងតម្រូវការហិរញ្ញប្បទានរបស់អតិថិជន។ បំណុលឯកជនក្នុងប្រព័ន្ធធនាគារទាំងនោះ ត្រូវបានបែងចែក ឬធ្វើពិពិធកម្ម​​ ទៅតាមវិស័យសំខាន់នានានៅក្នុងសេដ្ឋកិច្ច។ ក្នុងនោះ បំណុលសម្រាប់ការទិញផ្ទះជាកម្មសិទ្ធិផ្ទាល់ខ្លួនមានចំនួន១៣,៥ភាគរយ, ការជួញដូរអចលនទ្រព្យចំនួន៩,៨ភាគរយ, សំណង់ចំនួន៩,៥ភាគរយ, ការជួញដូររាយមាន១៧,៦ភាគរយ, ការជួញដូរដុំមាន៩ភាគរយ, វិស័យកសិកម្មមាន ៩ ភាគរយ, ការឱ្យខ្ចីជាបុគ្គលមាន ៩,៨ភាគរយ និងវិស័យកម្មន្តសាលមាន ៤,៤ភាគរយ, វិស័យសណ្ឋាគារ និងភោជនីយដ្ឋានមាន ៤ភាគរយ...ផងដែរ។ នេះបើតាមធនាគារជាតិ។ ជាមួយនឹងការកើនឡើងនៃបំណុលឯកជននេះ ក៏មានការកើនឡើងនៃឥណទាន មិនដំណើរការ(កម្ចីខូច)ផងដែរ។ ជាក់ស្តែងនៅក្នុងឆ្នាំ២០២៣ ឥណទានមិនដំណើរការបានកើនដល់ ៥,៤ភាគរយ សម្រាប់វិស័យធនាគារ និង៦,៧ភាគរយ សម្រាប់វិស័យមីក្រូហិរញ្ញវត្ថុ។ ធនាគារជាតិបានបញ្ជាក់ថា៖«ការកើនឡើងនៃឥណទានខូចនេះ គឺដោយសារការបញ្ចប់នូវវិធានការរៀបចំឥណទានឡើងវិញ និងការថមថយកំណើនឥណទាន»។ ដ្បិតមានការកើនឡើងនៃបំណុលឯកជន ជាមួយនឹងការខូចឥណទានរបស់ពលរដ្ឋក្តី ក៏ប៉ុន្តែធនាគារជាតិ បានអះអាងថា ប្រព័ន្ធធនាគារនៅកម្ពុជា បន្តរក្សាបាននូវភាពធន់​ និងមានវឌ្ឍនភាពជាលំដាប់ ដែលធានាដល់ការរក្សាចីរភាពហិរញ្ញប្បទាន និងសេវាហិរញ្ញវត្ថុចាំបាច់នានា ក្នុងការរួមចំណែកគាំទ្រសកម្មភាពសេដ្ឋកិច្ចជាតិ។ ក្នុង​ពិធីបើកសន្និបាតបូកសរុបលទ្ធផលការងារប្រចាំឆ្នាំ២០២៣ របស់ធនាគារជាតិ នៅថ្ងៃទី២៦មករា លោកស្រី ជា សិរី ទេសាភិបាលធនាគារជាតិនៃកម្ពុជា​ បាននិយាយយ៉ាងដូច្នេះ៖ «​ ទោះជាយ៉ាងណា កំណើនឥណទាននៅតែបន្តដើរតួនាទីយ៉ាងសំខាន់ ក្នុងការរួមចំណែកជំរុញវិស័យផលិតកម្ម ដូចជាវិស័យកម្មន្តសាល និងកសិកម្ម នៅតែមានកំណើនក្នុងអត្រា២ខ្ទង់ ។ ទន្ទឹមនេះ ឥណទានមិនដំណើរការ ក៏បានបន្តកើនឡើងដែលតម្រូវឱ្យមានការយកចិត្តទុកដាក់ខ្ពស់លើការត្រួតពិនិត្យ ធនាគារ និងធ្វើការ Stress Test ជាប់ជាប្រចាំ, ការតាមដានវាយតម្លៃឱ្យបានស៊ីជម្រៅលើហានិភ័យប្រទាក់ក្រឡា ក៏ដូចជាទាមទារឱ្យគ្រឹះស្ថានធនាគារ និងហិរញ្ញវត្ថុមានការប្រុងប្រយ័ត្នខ្ពស់បន្ថែមទៀត»។ ​ លោកស្រី ជា សិរី បានបញ្ជាក់ថា ប្រឈមនឹងបញ្ហាទាំងនេះ ធនាគារជាតិបានកែសម្រួលការវាយតម្លៃហានិភ័យឥណទាន ដោយបន្ទាបហានិភ័យ ក្នុងការផ្តល់ឥណទានទៅកាន់វិស័យអាទិភាព ដូចជាកសិកម្ម អប់រំ និងសហគ្រាសធុនតូច និងមធ្យមជាដើម។ ជាមួយគ្នានេះ បទប្បញ្ញាត្តិប្រុងប្រយ័ត្នមួយចំនួន ត្រូវបានអនុគ្រោះ ដើម្បីផ្តល់សន្ទនីយភាពដល់គ្រឹះស្ថានធនាគារ និងហិរញ្ញវត្ថុកាន់តែច្រើន​ ក្នុងការរួមចំណែកគាំទ្រសកម្មភាពសេដ្ឋកិច្ច ក៏ដូចជាពង្រឹងការការពារហានិភ័យនានា។ ក្នុងនោះរួមមាន ការបន្តអនុវត្តទ្រនាប់ដើម Conservation ត្រឹម ១,២៥ភាគរយ, ការបន្ថយអត្រាប្រាក់បម្រុងកាតព្វកិច្ចជារូបិយប័ណ្ណមក ៧ភាគរយ និងការអនុញ្ញាតឱ្យរៀបចំឥណទានឡើងវិញ ចំពោះវិស័យទេសចរណ៍នៅខេត្ត​សៀមរាប។ គួរជម្រាបថា គិតត្រឹមដំណាច់ឆ្នាំ២០២៣ ទ្រព្យសកម្មរបស់គ្រឹះស្ថានធនាគារ និងហិរញ្ញវត្ថុបានឡើង ដល់៣៤៦,៧ ទ្រីលានរៀល (៨៤,៣ពាន់លានដុល្លារ) កើន៨,៦ភាគរយ ធៀបនឹងឆ្នាំ២០២២។ ក្នុងនោះវិស័យធនាគារ មានសមាមាត្រ ៩១,៨ភាគរយ, វិស័យមីក្រូហិរញ្ញវត្ថុ ៧,៦ភាគរយ និងវិស័យភតិសន្យាហិរញ្ញវត្ថុ ០,៦ភាគរយ។ ឥណទានទៅកាន់វិស័យចម្បងៗ មានកំណើន ៤,៨ភាគរយ ដល់ ២៣៧,២ ទ្រីលានរៀល (៥៧,៦ ពាន់លានដុល្លារ) និងប្រាក់បញ្ញើអតិថិជនកើនឡើង ១៣,១ភាគរយ ដល់ ១៩៧,២ ទ្រីលានរៀល (៤៧,៩ ពាន់លានដុល្លារ)។ ស្ថានភាពដើមទុនរបស់ប្រព័ន្ធធនាគារ បន្តរក្សាបានភាពរឹងមាំ ដោយអនុបាតសាធនភាពមានកម្រិតខ្ពស់ដល់ ២២,៧ភាគរយ សម្រាប់វិស័យធនាគារ និង ២៥,៤ភាគរយ សម្រាប់វិស័យមីក្រូហិរញ្ញវត្ថុ ខ្ពស់ជាងកម្រិតកំណត់នៃបទប្បញ្ញត្តិ (១៥ភាគរយ) ស្របពេលដែលទ្រនាប់ដើមទុន ត្រូវបានបន្តអនុវត្តឡើងវិញក្នុងកម្រិត ១,២៥ភាគរយ នៃទ្រព្យសកម្មថ្លឹងតាម​ទម្ងន់ហានិភ័យ។ ជារួមគ្រឹះស្ថានធនាគារ និងហិរញ្ញវត្ថុបានបន្តចូលរួមលើកកម្ពស់បរិយាបន្នហិរញ្ញវត្ថុជាលំដាប់ ដែលឆ្លុះបញ្ចាំង តាមរយៈកំណើននៃចំនួនគណនីប្រាក់បញ្ញើអតិថិជនដល់ ១៨,៩ លានគណនី និងគណនីឥណទានអតិថិជនដល់ ៣,៩ លានគណនី។ បើតាមធនាគារជាតិ៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  ឥណទានរបស់វិស័យឯកជន ក្នុងប្រព័ន្ធធនាគារ និងហិរញ្ញវត្ថុនៅកម្ពុជា បានឡើងដល់ ២៣៧,២ទ្រីលានរៀល (៥៧,៦ពាន់លានដុល្លារអាម៉េរិក) ក្នុងឆ្នាំ២០២៣។ ទំហំនេះ បានកើនក្នុងអត្រា៤,៨ភាគរយ ធៀបនឹងឆ្នាំ២០២២ មានបំណុលឯកជនចំនួន ​៥៦,១ពាន់លានដុល្លារ។ នេះបើយោងតាមរបាយការណ៍ប្រចាំឆ្នាំ២០២៣ របស់ធនាគារជាតិនៃកម្ពុជា(NBC) ដែលទើបចេញផ្សាយនាព្រឹកថ្ងៃទី៣០មករានេះ។
#
# Predicted Summary:
#  លោក សិរី ទេសាភិបាលធនាគារជាតិនៃកម្ពុជា បានបញ្ជាក់ថា ការកើនឡើងនៃបំណុលឯកជនក្នុងប្រព័ន្ធធនាគារកម្ពុជា គឺដោយសារការងើបឡើងវិញនៃសកម្មភាពសេដ្ឋកិច្ច និងតម្រូវការហិរញ្ញប្បទាន។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 3 ---
# Full Article:
#  អត្ថបទទាក់ទង តៃវ៉ាន់ ព្រមាន​សូ​លូ​ម៉ុ​ន​ចំៗ «​ប្រយ័ត្ន​ធ្លាក់​ក្នុង​អន្ទាក់​បំណុល​ចិន​» ​ក្រសួងការបរទេស​តៃវ៉ាន់ តាមរយៈ​អ្នកនាំពាក្យ​របស់ខ្លួន នៅ​ថ្ងៃ​៦ កញ្ញា បាន​ព្រមាន រដ្ឋ​កោះ​សូ​លូ​ម៉ុ​ន ថា​អាច​នឹង​ធ្លាក់​ចូលក្នុង​អន្ទាក់​បំណុល​របស់​ចិន នៅពេលដែល​រដ្ឋ​កោះ​ប៉ាស៊ីហ្វិក​មួយ​នេះ ផ្តាច់ទំនាក់ទំនង​ការទូត​ពី​តៃវ៉ាន់​។ ការព្រមាន​របស់​តៃវ៉ាន់ ធ្វើឡើង​បន្ទាប់ពី សូ​លូ​ម៉ុ​ន ដាក់​ផែនការ​ងាក​មក​ផ្សារភ្ជាប់​ជាមួយនឹង​ចិន ដើម្បី​ទទួលបាន​ផលប្រយោជន៍​សម្រាប់​ការអភិវឌ្ឍ​ប្រទេស​របស់ខ្លួន​។​ ​តាម​ការចុះផ្សាយ​របស់​ភ្នាក់ងារ​ព័ត៌មាន Reuters អ្នកនាំពាក្យ​ក្រសួងការបរទេស​តៃវ៉ាន់ លោកស្រី Joanne Ou ក្រៅពី​ព្រមាន​ពី​ការ​ផុងខ្លួន​ជាមួយនឹង​អន្ទាក់​បំណុល លោកស្រី ក៏បាន​លើកឡើង​ពី​អំណះអំណាង និង​ផល​លំបាក​ដែល​រដ្ឋ​មួយចំនួន​ប្រឈម​នៅពេល​ទទួលបាន​ជំនួយ​អភិវឌ្ឍ​ពី​ចិន ជាពិសេស​លើ​វិស័យ​ហេដ្ឋារចនាសម្ព័ន្ធ​។​ ​ លោកស្រី អះអាងថា ហេដ្ឋារចនាសម្ព័ន្ធ ដែល​ចិន សន្យា​កសាង​ឲ្យ​បណ្តា​ប្រទេស​មួយចំនួន​កន្លងមក បាន​បណ្តាល​ឲ្យ​មានការ​បំផ្លិចបំផ្លាញ​ប្រព័ន្ធ​អេកូ​ក្នុងស្រុក និង​ថែមទាំង​បាន​បំពាន​អធិបតេយ្យ​របស់​រដ្ឋ​ទទួល​ជំនួយ​ទៀតផង​។ ​ ជុំវិញ​សេចក្តីថ្លែងការណ៍​របស់​តៃវ៉ាន់ មិនបាន​ធ្វើ​ឲ្យ​ចិន ផ្លាស់ប្តូរ​អ្វី​ឡើយ​។ នៅ​ថ្ងៃ​៦ កញ្ញា​ដដែល​នោះ អ្នកនាំពាក្យ​ក្រសួងការបរទេស​រប​ស់​ចិន លោក Geng Shuang បាន​តប​វិញ​ថា ការលើកឡើង​របស់​តៃវ៉ាន់ គ្មាន​បានការ​អ្វី​ឡើយ​។ អ្នកនាំពាក្យ បាន​សង្កត់ធ្ងន់ថា រដ្ឋាភិបាល​ចិន បាន​ត្រៀមខ្លួន​រួចជាស្រេច​ក្នុងការ​អភិវឌ្ឍ​ទំនាក់ទំនង​ជាមួយនឹង​ប្រទេស​ជុំវិញ​ពិភពលោក ដោយ​លើ​មូលដ្ឋាន​នៃ​គោលការណ៍​ចិន​តែមួយ​។ ​ គួរ​ជម្រាប​ថា បច្ចុប្បន្ន តៃវ៉ាន់ នៅសល់តែ​១៧​ប្រទេស​ទៀត​ប៉ុណ្ណោះ ដែល​នៅមាន​សម្ព័ន្ធភាព​ការទូត និង​ទទួលស្គាល់ថា តៃវ៉ាន់ ជា​រដ្ឋ​ស្របច្បាប់​របស់​ពិភពលោក​។ ប៉ុន្មាន​ឆ្នាំ​ចុងក្រោយ​នេះ តៃវ៉ាន់ បាន​បាត់បង់​សម្ព័ន្ធមិត្ត​ជា​បន្តបន្ទាប់ រួមមាន​ដូចជា ប៉ា​ណា​ម៉ា​, អែល​សាល់​វាល់​ឌ័​រ និង​សាធារណរដ្ឋ​ដូ​មី​និក ។ ចុងក្រោយ ហៃ​ទី ក៏​ត្រូវបាន​ជឿជាក់ថា នឹង​ផ្តាច់ទំនាក់ទំនង​ជាមួយនឹង​តៃវ៉ាន់ ដូច​រដ្ឋ​កោះ​សូ​លូ​ម៉ុ​ន​ផងដែរ ពោលគឺ​បើ​រដ្ឋ​ទាំងពីរ ពិតជា​នឹង​ចាក​ចេញពី​ចំណង​ជាមួយនឹង​តៃវ៉ាន់​មែន តៃវ៉ាន់ នឹង​នៅសល់តែ​រដ្ឋ​១៥​ទៀត​ប៉ុណ្ណោះ​។​ ​ អ្វីដែល​គួរ​ឲ្យ​កត់សម្គាល់​នោះ ការបាត់បង់​សម្ព័ន្ធមិត្ត​ជា​បន្តបន្ទាប់​នេះ ត្រូវបាន​តៃវ៉ាន់​ចោទថា ដោយសារតែ​នយោបាយ​ការទូត​ទឹក​លុយ​របស់​ចិន​។ ពោលគឺ ដោយសារតែ​ចិន ព្យាយាម​ចែចូវ​ជាមួយនឹង​រដ្ឋ​ដៃគូ​របស់​តៃវ៉ាន់ ដោយ​ត្រូវអនុវត្ត​គោលនយោបាយ​ចិន​តែមួយ (​តៃវ៉ាន់ គ្រាន់តែ​ជា​ផ្នែក​មួយ​របស់​ចិន​ប៉ុណ្ណោះ​) ជាមួយនឹង​ថ្នូរ​ជំនួយ និង​កម្ចី​អភិវឌ្ឍ​របស់​រដ្ឋាភិបាល​ចិន​៕ ​ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  មហាអំណាច​ចិន ហាក់​មិនសូវ​ជា​ខ្វាយខ្វល់​ទៅនឹង​សារ​ព្រមាន និង​សេចក្តីថ្លែងការណ៍​ពាក់ព័ន្ធ​របស់​កោះ​តៃវ៉ាន់​លើ​គោលនយោបាយ​ការទូត​ប៉ុន្មាន​នោះទេ​។ អ្វីដែល​ចិន ផ្តោត​សំខាន់បំផុត​នោះ គឺ​ការអភិវឌ្ឍ​ទំនាក់ទំនង​ការទូត​ឲ្យ​កាន់តែច្រើន ស្របតាម​គោលនយោបាយ ចិន​តែមួយ ដែល​ក្រុង​ប៉េកាំង អះអាងថា មានការ​ទទួលស្គាល់​ដោយ​សកល​។​
#
# Predicted Summary:
#  លោក Geng Shuang អ្នកនាំពាក្យ ក្រសួងការបរទេស តៃវ៉ាន់ បាន ព្រមាន រដ្ឋ កោះ សូ លូ ម៉ុ ន ថា អាច នឹង ធ្លាក់ ចូលក្នុង អន្ទាក់ បំណុល របស់ ចិន នៅពេលដែល រដ្ឋ កោះ ប៉ាស៊ីហ្វិក មួយ នេះ ផ្តាច់ទំនាក់ទំនង ការទូត ពី តៃវ៉ាន់ ។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 4 ---
# Full Article:
#  ការលក់រថយន្តអគ្គិសនីចិន បានកើនឡើងយ៉ាងខ្លាំងនៅលើទីផ្សារអន្តរជាតិ នៅក្នុងឆ្នាំ២០២៣។ គ្រាន់តែក្រុមហ៊ុនអគ្គិសនីចិន BYD បានលក់រថយន្តអគ្គិសនីរហូតដល់ ១,៦២លានគ្រឿង ខណៈក្រុមហ៊ុនចិនផ្សេងទៀត ក៏ទទួលជោគជ័យខ្លាំងដែរ។ ទាក់ទិននឹងបញ្ហានេះ នាយកប្រតិបត្តិក្រុមហ៊ុនអគ្គិសនីអាម៉េរិក Tesla លោក Elon Musk បានចាត់ទុកក្រុមហ៊ុនផលិតរថយន្តចិន ជាអាជីវកម្មមានភាពប្រកួតប្រជែងបំផុត ដោយទទួលបានជោគជ័យខ្លាំងនៅអន្តរជាតិ។ បើទោះបីជាមាន ការដាក់ពន្ធនាំចូល និងរបាំងពាណិជ្ជកម្មពីប្រទេសនានា ក៏ក្រុមហ៊ុនចិននៅតែទទួលបានជោគជ័យ។ «និយាយដោយស្មោះត្រង់! ខ្ញុំគិតថា ប្រសិនបើមិនមានរបាំងពាណិជ្ជកម្មទេ ពួកគេនឹងកម្ទេចក្រុមហ៊ុនរថយន្តផ្សេងទៀត នៅក្នុងពិភពលោក ពួកគេពិតជាពូកែណាស់»។ លោក Elon Musk បានព្រមានបែបនេះ នៅថ្ងៃទី២៤ ខែមករា ក្នុងកម្មវិធីមួយក្រោយពេលក្រុមហ៊ុនរថយន្តអគ្គិសនី BYD លក់បានរថយន្តច្រើនជាងគេបំផុត នៅត្រីមាសទី៤ ក្នុងឆ្នាំ២០២៣។ នៅក្នុងត្រីមាសទី៤ ឆ្នាំ២០២៣ ក្រុមហ៊ុន BYD លក់រថយន្តបានចំនួន ៥២៦ពាន់គ្រឿង ដែលច្រើនជាងក្រុមហ៊ុន Tesla ដែលលក់បានត្រឹមតែ ៤៨៥ពាន់គ្រឿងប៉ុណ្ណោះ។ ក្រុមហ៊ុន Tesla បានចាប់ផ្តើមបន្ទាបតម្លៃរថយន្តរបស់ខ្លួន កាលពីឆ្នាំមុន ក្នុងគោលបំណងទាក់ទាញអ្នកទិញ ដែលរងផលប៉ះពាល់ពីការកើនឡើងអត្រាការប្រាក់។ ក្រុមហ៊ុន Tesla គ្រោងផលិតម៉ូដែលរថយន្តដ៏ពេញនិយម ដែលមានតម្លៃថោក ចាប់ពីពាក់កណ្តាលឆ្នាំ២០២៥ ដើម្បីប្រកួតប្រជែងជាមួយនឹងដៃគូដ៏មានប្រជាប្រិយភាព ដូចជាក្រុមហ៊ុន BYD។ លោក Musk បានបញ្ជាក់ថា Tesla ​នឹងផលិតម៉ូដែលរថយន្តអគ្គិសនីជំនាន់ថ្មី ក្នុងឆមាសទី២ ឆ្នាំក្រោយ។ យ៉ាងណាមិញ ក្រុមហ៊ុនរថយន្តអគ្គិសនីរបស់ចិន នៅតែអាចគ្រប់គ្រងការចំណាយបានប្រសើរជាង ដោយសារខ្សែច្រវាក់ផ្គត់ផ្គង់មានស្ថិរភាព។ លោក Ross Gregory នៅក្រុមហ៊ុនប្រឹក្សា New Electric Partners បានប្រាប់ Reuters ថា៖«ហេដ្ឋារចនាសម្ព័ន្ធសម្រាប់ផលិតសម្ភារថ្មសាករថយន្តនៅចិន មានភាពចាស់ទុំ និងមានស្ថិរភាពជាច្រើនទសវត្សរ៍មកហើយ​»​។ ថ្មីៗនេះ ក្រុមហ៊ុនចិន SAIC Motor កំពុងបញ្ជាទិញកប៉ាល់ សម្រាប់ដឹករថយន្តបន្ថែមទៀត ដើម្បីសន្សំសំចៃថ្លៃដឹកជញ្ជូនទៅក្រៅប្រទេស។ បើតាមលោក Spencer Imel នៅក្រុមហ៊ុនប្រឹក្សា Lansgton បច្ចុប្បន្នការយល់ដឹងអំពីម៉ាកយីហោរបស់ក្រុមហ៊ុនផលិតរថយន្តចិន នៅអាម៉េរិក មានកម្រិតទាបណាស់។ ដូច្នេះហើយ ក្រុមហ៊ុនចិនទាំងនេះ នឹងត្រូវធ្វើដំណើរលើផ្លូវវែងឆ្ងាយ ប្រសិនបើពួកគេចង់ទទួលបានចំណែកទីផ្សារនៅអាម៉េរិក។ «ក្រុមហ៊ុនទាំងនេះ កំពុងទទួលបានអត្ថប្រយោជន៍ពីតម្រូវការខ្ពស់នៅចិន ជាមួយនឹងរបកគំហើញដូចជាបច្ចេកវិទ្យានៅក្នុងរថយន្ត និងការប្តូរប្រព័ន្ធថ្មសាក។ យើងគិតថា នេះនឹងក្លាយជាកត្តាសំខាន់ និងខុសគ្នាសម្រាប់កំណើនរបស់ពួកគេនៅបរទេសនាពេលអនាគត»។ លោក Imel បានបញ្ជាក់ប្រាប់ Reuters បែបនេះ។ កាលពីថ្ងៃទី២៤ ខែមករា លោក Musk បាននិយយាថា Tesla មិនទាន់ច្បាស់លាស់នោះទេ ក្នុងការសហការជាមួយដៃគូប្រកួតប្រជែងចិន។ យ៉ាងណាក៏ដោយ លោក Elon Musk ថា Tesla មានឆន្ទៈក្នុងការចែករំលែកប្រព័ន្ធសាកថ្មរបស់ខ្លួន និងបច្ចេកវិទ្យាមួយចំនួនទៀតជាមួយចិន ដូចជាបច្ចេកវិទ្យាបើកបរដោយខ្លួនឯងជាដើម។ ការលើកឡើងរបស់លោក Musk ធ្វើឡើងក្នុងបរិបទដែលបេក្ខជនប្រធានាធិបតីអាម៉េរិក កំពុងប្រកួតប្រជែងប្រជាប្រិយភាព ដើម្បីទទួលបានការគាំទ្រពីអ្នកបោះឆ្នោត។ ប្រធានាធិបតី ចូ បៃឌិន បាននិយាយថា លោកមិនឱ្យចិនគ្រប់គ្រងទីផ្សាររថយន្តអគ្គិសនី ស្របតាមបំណងឡើយ។ អតីតប្រធានាធិបតីអាម៉េរិក លោក ដូណាល់ ត្រាំ ក៏បានផ្តល់សញ្ញាដែរថា លោកនឹងដំឡើងពន្ធនាំចូល ប្រសិនបើលោកជាប់ឆ្នោតឡើងវិញ។ លោក​បាន​អំពាវនាវ​ឲ្យ​មាន​ការ​យក​ពន្ធ ១០ ភាគរយ ​លើ​ទំនិញនាំចូលអាម៉េរិកទាំងអស់។ លើសពីនេះ អឺរ៉ុប​ក៏​មានការ​ប្រុង​ប្រយ័ត្ន​កាន់តែខ្លាំង ចំពោះ​ក្រុមហ៊ុន​រថយន្ត​អគ្គិសនី​របស់​ចិន។ កាលពីឆ្នាំមុន គណៈកម្មការអឺរ៉ុបបានបើកការស៊ើបអង្កេតមួយ ដើម្បីពិនិត្យមើល​វិធានការដាក់ពន្ធលើរថយន្តអគ្គិសនីចិន៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  នាយកប្រតិបត្តិក្រុមហ៊ុន Tesla លោក Elon Musk នៅថ្ងៃទី២៤ ខែមករា បានសរសើរក្រុមហ៊ុនផលិតរថយន្តអគ្គិសនីចិនថា បានទទួលភាពជោគជ័យដ៏អស្ចារ្យ នៅក្នុងទីផ្សារអន្តរជាតិ។ ប៉ុន្តែមេក្រុមហ៊ុនលក់រថយន្តអគ្គិសនីរូបនេះ ក៏ព្រមានផងដែរថា រថយន្តអគ្គិសនីចិន នឹងកម្ទេចគូប្រជែង បើគ្មានរបាំងពន្ធពាណិជ្ជកម្ម។
#
# Predicted Summary:
#  Tesla បានប្រកាសថា ក្រុមហ៊ុនផលិតរថយន្តអគ្គិសនីចិន BYD បានលក់បានរថយន្តច្រើនជាងគេបំផុតនៅត្រីមាសទី៤ ឆ្នាំ២០២៣ ក្នុងត្រីមាសទី៤ ឆ្នាំ២០២៣។ នេះបើតាមលោក Elon Musk នៅថ្ងៃទី២៤ ខែមករា។
# ROUGE-1: 0.8571
# ROUGE-2: 0.4
# ROUGE-L: 0.8571
# ----------------------------------------------------------------------------------------------------
#
# --- Article 5 ---
# Full Article:
#  យ៉ាងណាមិញ​សម្រាប់​ប្រទេស​អាស៊ាន​វិញ​ក្នុង​រយៈពេល​មួយ​ទសវត្ស​ចុងក្រោយ​នេះ​មាន​ប្រទេស​មួយចំនួន​បាន​ផ្លាស់ប្តូរ​មេដឹកនាំ​ជា​បន្តបន្ទាប់​រីឯ​មួយចំនួន​មេដឹកនាំ​គឺ​នៅ​ដដែល​ដោយសារតែ​មិនមាន​ការកំណត់​អាណត្តិ​នៃ​ការដឹកនាំ​និង​ប្រជាប្រិយភាព​ក៏ដូចជា​សមិទ្ធផល​ក្រោម​ការដឹកនាំ​របស់​មេដឹកនាំ​ទាំងនោះ។ខាងក្រោម​នេះ​ជា​មេដឹកនាំ​បច្ចុប្បន្ន​របស់​ប្រទេស​នៅក្នុង​ស្ថាប័ន​អាស៊ាន៖ ១. ព្រះមហាក្សត្រ Hassanal Bolkiah បាន​ឡើងកាន់តំណែង​ជា​ប្រមុខរដ្ឋ(សេ្ត​ច)ផង និង​ប្រមុខ​រដ្ឋាភិបាល (នាយករដ្ឋមន្ត្រី) ផង តាំងពី​ឆ្នាំ ១៩៦៨ ២ . លោកនាយក​មន្ត្រី ហ៊ុន សែន បាន​ឡើងកាន់តំណែង​ជា​នាយករដ្ឋមន្ត្រី​កម្ពុជា​តាំងពី​ឆ្នាំ ១៩៨៥ ៣. លោកនាយក​រដ្ឋមន្ត្រី លី សៀន ឡុង (Lee Hsien Loong) បាន​ឡើងកាន់តំណែង​ជា​នាយករដ្ឋមន្ត្រី​សិង្ហ​បុរី តាំងពី​ឆ្នាំ២០០៤ ៤. លោកនាយក​មន្ត្រី ង្វៀង តាន់ ឌុ​ង (Nguyen Tan Dung) បាន​ឡើងកាន់តំណែង​ជា​នាយករដ្ឋមន្ត្រី​វៀតណាម​តាំងពី​ឆ្នាំ ២០០៦ ៥ . លោកនាយក​រដ្ឋមន្ត្រី ណា​ជីប រ៉ា​ហ្សា​ក់ (Najib Razak) បាន​ឡើងកាន់តំណែង​ជា​នាយករដ្ឋមន្ត្រី​របស់​ម៉ាឡេស៊ី ឆ្នាំ២០០៩ ៦. លោកនាយក​រដ្ឋមន្ត្រី ថុង​សឹង ថា​ម​ម៉ា​វង់ (Thongsing Thammavong) បាន​ឡើងកាន់តំណែង​ជា​នាយករដ្ឋមន្ត្រី​ឡាវ​ឆ្នាំ២០១០ ៧ . លោក​ប្រធានាធិបតី Benigno "Noynoy" Aquino បាន​ឡើងកាន់តំណែង​ជា​ប្រធានាធិបតី​ហ្វីលីពីន តាំងពី​ឆ្នាំ២០១០ ៨. លោក​ប្រធានាធិបតី​ថេ​ន​សេន (Thein Sein) បាន​ក្លាយជា​ប្រធានាធិបតី​មី​យ៉ាន់​ម៉ា​តាំងពី​ឆ្នាំ២០១១ ៩. លោកនាយក​រដ្ឋមន្ត្រី​ប្រា​យុទ្ធ​ចាន់​អូ​ចា​បាន​ឡើងកាន់តំណែង​ជា​នាយករដ្ឋមន្ត្រី​ថៃ​ដោយ​រដ្ឋប្រហារ​យោធា​ឆ្នាំ២០១៤ ១០ .លោក​ប្រធានាធិបតី​Joko Widodoបាន​កាន់តំណែង​ជា​ប្រធានាធិបតី​របស់​ឥណ្ឌូនេស៊ី​នៅ​អាណត្តិ​ដំបូង​ឆ្នាំ ២០១៤៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  ជាទូទៅ​ប្រទេសនីមួយៗតែងតែមាន​ប្រព​ន្ធ័​នយោបាយខុសៗគ្នា​តួយ៉ាង​ដូចជា​ប្រទេស​នៅក្នុង​ស្ថាប័ន​អាស៊ាន​មាន​ប្រទេស​ខ្លះ​ប្រកាន់​របប​សាធារណរដ្ឋ​ប្រទេស​ខ្លះ​ប្រកាន់​របបរាជានិយម​ហើយ​ក្នុងនោះ​មាន​ប្រទេស​ខ្លះ​តួអង្គ​សំខាន់​នយោបាយ​ជា​ប្រមុខរដ្ឋ(ប្រធានាធិបតី​ឬ​សេ្ត​ច) រីឯ​មួយចំនួនទៀត​តួអង្គ​សំខាន់​ជា​ប្រមុខ​រដ្ឋាភិបាល (នាយករដ្ឋមន្ត្រី)ទៅវិញ។កត្តា​ទាំងនេះ​អាស្រ័យទៅលើ​ច្បាប់​របស់​ប្រទេស​ទាំងនោះ។
#
# Predicted Summary:
#  លោកនាយក រដ្ឋមន្ត្រី ថុង សឹង ថា ម ម៉ា វង់ (Lee Hsien Loong) បាន ឡើងកាន់តំណែង ជា នាយករដ្ឋមន្ត្រី ឥណ្ឌូនេស៊ី នៅ អាណត្តិ ដំបូង ឆ្នាំ ២០២៤។ មេដឹកនាំ បច្ចុប្បន្ន របស់ ប្រទេស អាស៊ាន បាន ផ្លាស់ប្តូរ មេដឹកនាំ ជា បន្តបន្ទាប់ ដោយសារតែ មិនមាន ការកំណត់ អាណត្តិ នៃ ការដឹកនាំ របស់ មេដឹកនាំ ទាំងនោះ។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 6 ---
# Full Article:
#  លោក មុំ ពិទូរ្យ លម្អិត​ព័ត៌មាន​នេះ ស្ថានទូត​រុស្ស៊ី​ប្រចាំ​នៅ​ទីក្រុង​ដា​ម៉ាស​បាន​រង​ការខូចខាត​យ៉ាងដំណំ​ដោយសារ​ការ​ផ្លោង​គ្រាប់​របស់​កងកម្លាំងប្រដាប់អាវុធ​ប្រឆាំង​រដ្ឋាភិបាល​ស៊ី​រី​ម្សិលមិញ។ បើតាម​ការ​ឲ្យ​ដឹង​ពី​សំណាក់​អាជ្ញាធរ​តំបន់ និង​ក្រសួងការបរទេស​រុស្ស៊ី ការវាយប្រហារ​នេះ​បានធ្វើ​ឲ្យ​ខូចខាត​សំណង់​អាគារ​ទូត​រុស្ស៊ី ប៉ុន្តែ​សំណាងល្អ​មិនមាន​មន្ត្រី​ទូត​ណា​ម្នាក់​របួស​ឬ​ស្លាប់​ឡើយ។ យ៉ាងណាក៏ដោយ រដ្ឋាភិបាល​រុស្ស៊ី​បានបង្ហាញ​កំហឹង​ចំពោះ​ជន​ដែល​ហ៊ាន​វាយប្រហារ​ស្ថានទូត​រុស្ស៊ី និង​ប្រកាស​ថ្កោលទោស​អ្នក​នៅ​ពីក្រោយ​ការវាយប្រហារ​នេះ​ផងដែរ។ បើតាម​សេចក្តីថ្លែងការណ៍​របស់​ក្រសួង​ការ​ការបរទេស​រុស្ស៊ី ការវាយប្រហារ​ដោយ​បាញ់​គ្រាប់ផ្លោង​នេះ កើតឡើង​កាលពី​ម្សិលមិញ ហើយ​គ្រាប់​បាញ់​ផ្លោង​បាន​ចេញពី​តំបន់ Jobarដែល​កំពុង​ស្ថិតនៅក្រោម​ការគ្រប់គ្រង​របស់​ក្រុម​ប្រដាប់អាវុធ​ប្រឆាំង​រដ្ឋាភិបាល។ ក្នុង​សេចក្តីថ្លែងការណ៍​ដដែល​នោះ បាន​ថ្កោលទោស​សកម្មភាព​វាយប្រហារ​ប្រតិបត្តិការ​និង​បេសកម្ម​ការទូត​រុស្ស៊ី ដោយ​រុស្ស៊ី​ចាត់ទុក​ទង្វើ​នេះ​ជា​សកម្មភាព​ភេរវកម្ម​ផងដែរ។ គេ​មិនទាន់​អាចសន្និដ្ឋាន​បាន​ច្បាស់​នៅឡើយ​ទេ​ថា អ្នកណា​ជា​អ្នក​នៅ​ពីក្រោយ​នៃ​ការវាយប្រហារ​ឲ្យ​ពិតប្រាកដ ប៉ុន្តែ​ដោយសារ​ការបាញ់​ផ្លោង​ចេញពី​តំបន់​របស់​ក្រុម​ឧទ្ទាម ដូច្នេះ​គេ​ដាក់​ការសង្ស័យ​លើ​ក្រុម​ឧទ្ទាម​តែម្តងទៅ។ ហើយ​ម្យ៉ាង​ដោយសារ​ក្រុម​ឧទ្ទាម​មាន​ច្រើន​ក្រុម គេ​ក៏​នៅ​មិនអាច​ដឹងបាន​ឡើយ​ដែរ ថា​ក្រុម​ឧទ្ទាម​ទាំងនោះ​ស្ថិតក្រោម​ការជួយ​គាំទ្រ​របស់លោក​ខាងលិច​ឬ​យ៉ាងណា​នោះទេ។ ក្រុម​ឧទ្ទាម​ជាច្រើន​ក្រុមប្រឆាំង​រដ្ឋាភិបាល​លោក បា​សា អាល់​អាសាដ កើនឡើង​ច្រើន និង​បន្ត​វាយប្រហារ​កង​ម្លាំ​ង​រដ្ឋាភិបាល​ដើម្បី​ផ្តួលរំលំ​របប​ដឹកនាំ​បច្ចុប្បន្ននេះ។ សូម​រម្លឹក​ផងដែរ​ថា សហរដ្ឋអាមេរិក​និង​លោកខាងលិច​មួយចំនួន​ជា​ប្រទេស​សកម្ម​ជា​គេ​ដែល់​ផ្តល់ជំនួយ​ហិរញ្ញវត្ថុ និង​អាវុធ​យុទ្ធ​ភ័​ណ្ឌ​ដល់​កងកម្លាំង​ក្រុម​ឧទ្ទាម​ជាច្រើន​ក្រុម ដើម្បី​ប្រយុទ្ធ។ ក្រៅពី​ថ្កោលទោស​ករណី​ភេរវកម្ម អ្នកនាំពាក្យ​ក្រសួងការបរទេស​រុស្ស៊ី លោក AleksandrLukashevich បាន​ឲ្យ​ដឹងថា រដ្ឋាភិបាល​ក្រុង​ម៉ូស្គូ​ក៏បាន​បង្ហាញ​ការគាំទ្រ​ចំពោះ​រដ្ឋាភិបាល​ក្រុង​ដា​ម៉ាស​ផងដែរ ដោយ​រដ្ឋាភិបាល​នេះ​បានប្រកាសថា​ខ្លួន​បន្ត​សហការ​ជាមួយ​អាជ្ញាធរ​ក្រុង​ដា​ម៉ាស​ដើម្បី​តាម​កម្ចាត់​ក្រុម​ភេរវជន។ លោក​បាន​សង្កត់ធ្ងន់ថា រុស្ស៊ី​បន្ត​អំពាវនាវ​ឲ្យ​ភាគី​ពាក់ព័ន្ធ​ជាពិសេស​ក្រុមប្រឹក្សាសន្តិសុខ ឲ្យ​សហការគ្នា​ដើម្បី​កម្ចាត់​ក្រុម​ភេរវជន និង​ការពារ​សន្តិសុខ សន្តិភាព​ពិភពលោក។ ក្រោយ​ការវាយប្រហារ​ស្ថានទូត​រុស្ស៊ី រដ្ឋាភិបាល​ស៊ី​រី ប្រញាប់ប្រញាល់​ឆ្លើយតបភ្លាមៗ ដោយ​សន្យាថា​នឹង​បង្កើន​ការការពារ និង​រឹតបន្តឹង​សន្តិសុខ​តាម​ដែល​អាចធ្វើ​ទៅបាន​ដើម្បី​ការពារ​ស្ថានទូត​និង​មន្ត្រី​ទូត​រុស្ស៊ី​នៅក្នុង​ប្រទេស​ខ្លួន៕ លោក មុំ ពិទូរ្យ លម្អិត​ព័ត៌មាន​នេះ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  រដ្ឋាភិបាល​រុស្ស៊ី​ខឹងសម្បារ​ជាខ្លាំង​ក្រោយ​មានការ​វាយប្រហារ​ដោយ​គ្រាប់ផ្លោង​ប្រឆាំង​ស្ថានទូត​រុស្ស៊ី​ប្រចាំ​ប្រទេស​ស៊ី​រី​ក្នុង​រដ្ឋធានី​ដា​ម៉ាស​កាលពី​ម្សិលមិញ។ គ្រាប់ផ្លោង​បាញ់​ចេញពី​តំបន់​ដែល​ក្រុម​ប្រដាប់អាវុធ​ខុសច្បាប់​កាន់កាប់ ហើយ​គេ​សង្ស័យថា​ក្រុម​ទាំងនោះ​ជា​អ្នកបាញ់​គ្រាប់ផ្លោង​នោះ។ រុស្ស៊ី​បាន​ថ្កោលទោស និង​ចា​ត​ទុក​ការវាយប្រហារ​ជា​សកម្មភាព​ភេរវកម្ម និង​មិនអាច​លើកលែង​បានឡើយ។
#
# Predicted Summary:
#  ស្ថានទូត រុស្ស៊ី ប្រចាំ នៅ ទីក្រុង ដា ម៉ាស បាន រង ការខូចខាត យ៉ាងដំណំ ដោយសារ ការ ផ្លោង គ្រាប់ របស់ កងកម្លាំងប្រដាប់អាវុធ ប្រឆាំង រដ្ឋាភិបាល ស៊ី រី។ ការវាយប្រហារ នេះ បានធ្វើ ឲ្យ ខូចខាត សំណង់ អាគារ ទូត រុស្ស៊ី ដែល កំពុង ស្ថិតនៅក្រោម ការគ្រប់គ្រង របស់ ក្រុម ប្រដាប់អាវុធ ប្រឆាំង រដ្ឋាភិបាល ស៊ី រី។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 7 ---
# Full Article:
#  វីដេអូឃ្លីបមួយដែលត្រូវបានផ្សព្វផ្សាយនៅលើបណ្តាញសង្គមរបស់ចិន បង្ហាញពីរ៉បូតរាងស្វ៊ែរមួយដែលកំពុងដើរល្បាតតាមដងផ្លូវជាមួយប៉ូលីសក្នុងតំបន់ក្នុងទីក្រុង Wenzhou នៃខេត្ត Zhejiang ។ នេះជារ៉ូបូតដ៏ឆ្លាតវៃដែលអាចផ្លាស់ទីនៅលើដីដោយមិនចាំបាច់មានការគ្រប់គ្រងរបស់មនុស្ស។ បើតាមអនុប្រធានក្រុមល្បាតពិសេស លោក Huang Sufeng នៃប៉ូលីសស្រុក Lucheng ទីក្រុង Wenzhou រ៉ូបូតនេះមានទម្ងន់១២៥គីឡូក្រាម ហើយអាចរត់ក្នុងល្បឿនអតិបរមា ៣៥គីឡូម៉ែត្រក្នុងមួយម៉ោង។ នេះជាប្រភេទឧបករណ៍ជំនួយប៉ូលិសដែលអាចដោះស្រាយជាមួយគ្រោះថ្នាក់នៅចម្ងាយជិត។ ដោយផ្អែកលើតម្រូវការជាក់ស្តែង ឧបករណ៍ប៉ូលិសដូចជា កាំភ្លើង គ្រាប់បែកផ្សែង... ឧបករណ៍បំពងសំឡេងប្រេកង់ខ្ពស់ អាចដាក់នៅលើរ៉ូបូតនេះបាន។ វាក៏អាចតាមដាន ប្រយុទ្ធ ចាប់យក ប្រតិបត្តិការទាំងនៅលើដី និងក្រោមទឹក ដោយរួមបញ្ចូលទាំងការឃ្លាំមើល និងការប្រយុទ្ធផងដែរ។ លោក Huang Sufeng បានបន្ថែមថា លក្ខណៈពិសេសដ៏ធំបំផុតរបស់រ៉ូបូតរាងស្វ៊ែរនេះ វាមិនបាត់បង់មុខងាររបស់វាឡើយ បើទោះបីជាត្រូវបានវាយប្រហារនៅចម្ងាយជិតក៏ដោយ ហើយអាចផ្លាស់ទីដោយសេរីនៅក្នុងបរិយាកាសដ៏អាក្រក់ ឬហ្វូងមនុស្សដ៏ស្មុគស្មាញ ធ្វើឲ្យប្រសើរឡើងយ៉ាងខ្លាំងនូវសមត្ថភាពរបស់កងកម្លាំងប៉ូលិស ក្នុងការគ្រប់គ្រងស្ថានការណ៍នៅនឹងកន្លែង។ រ៉ូបូតនេះកំពុងស្ថិតក្នុងដំណាក់កាលសាកល្បង ហើយនឹងត្រូវបានធ្វើឱ្យប្រសើរឡើង និងបំពាក់ដោយឧបករណ៍ប៉ូលិសបន្ថែមដោយផ្អែកលើតម្រូវការជាក់ស្តែង។ បើតាមលោក Wang You សាស្ត្រាចារ្យរងនៃវិទ្យាស្ថានគ្រប់គ្រងវិទ្យាសាស្ត្រ និងវិស្វកម្មនៃសាកលវិទ្យាល័យ Zhejiang ដែលជាប្រធានក្រុមស្រាវជ្រាវ បន្ថែមពីលើសមត្ថភាពបង្កើនល្បឿនបានលឿន រ៉ូបូតនេះក៏អាចសម្របតាមគ្រប់ស្ថានភាពអាកាសធាតុដូចជា ភ្លៀង ព្រិល ព្យុះ និងដីដ៏អាក្រក់ដូចជាភក់ ថ្ម និងវាលខ្សាច់។ ក្រុមការងារក៏បានបង្កើតគំរូរ៉ូបូតរាងស្វ៊ែរចល័តតូចជាងមុន ដើម្បីបំពេញតម្រូវការផ្សេងៗគ្នាក្នុងស្ថានភាពកម្មវិធីផ្សេងៗ។ បច្ចុប្បន្ន តម្លៃនៃការផលិតរ៉ូបូតស្វ៊ែរមានចាប់ពីជាង ៤១៤០០ដុល្លារ ដល់ជាង ៥៥ ០០០ដុល្លារ។ ជាមួយនឹងការកែលម្អ និងការផ្លាស់ប្តូរជាបន្តបន្ទាប់ និងកាត់បន្ថយការចំណាយនៅពេលពង្រីកទំហំផលិតកម្ម សាស្ត្រាចារ្យរង Wang រំពឹងថា លទ្ធភាពនៃការប្រើប្រាស់រ៉ូបូតស្វ៊ែរនឹងពង្រីកដល់ឧបករណ៍ប្រើប្រាស់ក្នុងផ្ទះ ឬប្រដាប់ក្មេងលេង៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  រ៉ូបូតរាងស្វ៊ែរ ដែលអាចដំណើរការបានទាំងនៅលើដី និងក្រោមទឹក ជាមួយនឹងសមត្ថភាពក្នុងការតាមដាន ប្រយុទ្ធ នាពេលថ្មីៗនេះបានល្បាតជាមួយមន្រ្តីប៉ូលីសនៅក្នុងតំបន់ពាណិជ្ជកម្មមួយក្នុងខេត្ត Wenzhou ភាគខាងកើតប្រទេសចិន។ ជាមួយនឹងភាពប្រសើរឡើងនៃទំហំ និងមុខងារ រ៉ូបូតនេះត្រូវបានគេរំពឹងថានឹងត្រូវគេដាក់ឲ្យដំណើរច្រើនកន្លែង។
#
# Predicted Summary:
#  លោក Wang You សាស្ត្រាចារ្យរងនៃវិទ្យាស្ថានគ្រប់គ្រងវិទ្យាសាស្ត្រ និងវិស្វកម្មនៃសាកលវិទ្យាល័យ Zhejiang បានប្រកាសថា រ៉ូបូតរាងស្វ៊ែរដែលកំពុងដើរល្បាតតាមដងផ្លូវជាមួយប៉ូលីសក្នុងតំបន់ក្នុងទីក្រុង Wenzhou នៃខេត្ត Zhejiang។
# ROUGE-1: 0.3333
# ROUGE-2: 0.0
# ROUGE-L: 0.3333
# ----------------------------------------------------------------------------------------------------
#
# --- Article 8 ---
# Full Article:
#  Benzema បានចាកចេញពី Real Madrid ក្រោយរួបរស់អស់រយៈពេល១៤ឆ្នាំ បន្ទាប់ពីផ្ទេរពីក្លិប Lyon កាលពីឆ្នាំ២០០៩។ មុនចាកចេញពី Real Madrid នេះ Benzema រកបាន១គ្រាប់ឱ្យក្រុមតាមស្មើ ជាមួយក្រុម​ Athletic Bilbao ក្នុងលទ្ធផល១-១ នាទឹកដី Santiago Bernabeu នៅថ្ងៃទី៥ មិថុនា។ ក្រោយការចាកចេញនេះ មិនទាន់មានព័ត៌មានផ្លូវការណាមួយថា Benzema នឹងទៅចូលរួមជាមួយក្លិបណាដែរ។ ប៉ុន្តែតាមរយៈអ្នកកាសែតកីឡាល្បីមួយរូប ដែលមានសញ្ជាតិអ៊ីតាលី Fabrizio Romano ដែលបានសរសេរលើហ្វេសប៊ុកផ្លូវការខ្លួនថា Benzema នឹងចូលរួមជាមួយក្លិប Al Ittihad របស់លីគអារ៉ាប់ប៊ីសាអូឌីត ជាមួយនឹងតម្លៃខ្លួន ក្នុងកិច្ចសន្យា ២០០លានផោន រួមនឹងអត្ថប្រយោជន៍ផ្សេងទៀត។ ចំពោះការចាកចេញរបស់ខ្សែប្រយុទ្ធសញ្ជាតិបារាំងនេះ ក្លិប Real Madrid ក៏កំពុងចន្លោះប្រហោងតំបន់ប្រយុទ្ធផងដែរ។ សម្រាប់តំបន់ប្រយុទ្ធនេះ ត្រូវបានគេមើលឃើញ Real Madrid នឹងប្រមាញ់យកខ្សែប្រយុទ្ធសញ្ជាតិអង់គ្លេស Harry Kane មកជំនួស Benzema ។ Kane ស៊ុតបញ្ចូលបាន២៨០គ្រាប់ ក្នុងការបង្ហាញខ្លួន៤៣៥ប្រកួត ឱ្យក្រុម Spur ។ បើតាមការចុះផ្សាយរបស់ BBC ក្រៅពី Kane ក្លិបអធិរាជ ស មួយនេះ ក៏ដាក់គោលដៅយកខ្សែប្រយុទ្ធ Victor Osimhen, ខ្សែប្រយុទ្ធLautaro Martinez ពីInter , Kai Havertz ពី Chelsea និង Dusan Vlahovic ពីJuventus ។​ បច្ចុប្បន្ន Real ក៏កំពុងទាក់ទងជាមួយក្លិប Dortmund ដើម្បីនាំយកខ្សែបម្រើសញ្ជាតិអង់គ្លេស Jude Bellingham មកចូលរួមជាមួយក្រុមផងដែរ។ ក្រៅពី Benzema ក៏មានកីឡាករផ្សេងទៀត ដូចជា Eden Hazard, Marco Arsensio និង Mariano Diaz ក៏នឹងត្រូវចាកចេញពីក្លិប Real នារដូវក្តៅខាងមុខនេះដែរ ក្នុងរង្វង់តម្លៃខ្លួន ជាង៧០លានអឺរ៉ូ។ នេះបើតាម BBC។ ក្នុងវ័យ៣៥ឆ្នាំ Benzema បានទទួលពានរង្វាន់ Ballon d’Or ផងដែរ កាលពីឆ្នាំ២០២២ ។ Benzema ធ្លាប់ជួយ Real ឈ្នះពានរង្វាន់ Lali ga ៤លើក និង Champion League ៥លើក៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  ខ្សែប្រយុទ្ធសញ្ជាតិអង់គ្លេស Harry Kane ស្ថិតនៅក្នុងគោលដៅរបស់ក្លិបអធិរាជ ស Real Madrid ក្នុងយកមកជំនួសតំណែងខ្សែប្រយុទ្ធសញ្ជាតិបារាំង Karim Benzema នារដូវកាលក្រោយនេះ។
#
# Predicted Summary:
#  ខ្សែប្រយុទ្ធសញ្ជាតិបារាំង Harry Kane បានចាកចេញពី Real Madrid ក្រោយរួបរស់អស់រយៈពេល១៤ឆ្នាំ បន្ទាប់ពីផ្ទេរពីក្លិប Real Madrid ក្នុងលទ្ធផល១-១ នាទឹកដី Santiago Bernabeu នៅថ្ងៃទី៥ មិថុនា។
# ROUGE-1: 0.5714
# ROUGE-2: 0.5
# ROUGE-L: 0.5714
# ----------------------------------------------------------------------------------------------------
#
# --- Article 9 ---
# Full Article:
#  បើតាមសេចក្តីថ្លែងការណ៍មួយ ក្រុមប្រឹក្សាស្ថិតនៅក្នុងទីក្រុង Mangaratiba ​បានដាក់ការផាកពិន័យចំនួន ៤ សម្រាប់ការប៉ះពាល់ដល់បរិស្ថានធ្ងន់ធ្ងរដោយការកសាងស្រះសិប្បនិមិ្មតមួយនៅក្នុងដីផ្ទះរបស់ Neymar Jr។ «ការដាក់ទណ្ឌកម្មមានតម្លៃសរុបមានប្រមាណ ១៦លានរ៉ៃ (Reais) ប្រមាណ ៣,៣លានដុល្លារ។»។ នេះបើតាមសេចក្តីថ្លែងការណ៍ដែលប្រកាសដោយព្រះរាជអាជ្ញាក្នុងទីក្រុង ​​Mangaratiba។ ដីផ្ទះវីឡាដ៏ធំស្គឹមស្គៃរបស់ខ្សែប្រយុទ្ធវ័យ ៣១ឆ្នាំ មានចម្ងាយប្រមាណ ១៣០គីឡូម៉ែត្រពីទីក្រុង Rio ហើយទីនោះក៏ជាតំបន់ទេសចរណ៍ថែមទៀត។ ការបំពានលើការជីកនេះ អាជ្ញាធរបានរាប់បញ្ចូលជាការអនុវត្តការងារស្ថិតក្រោមការត្រួតពិនិត្យបរិស្ថានដោយគ្មានការអនុញ្ញាតត្រឹមត្រូវពីសំណាក់អាជ្ញាធរពាក់ព័ន្ធ ចំពោះការជីកដី ការបង្ហូរទឹកទន្លេដោយគ្មានការអនុញ្ញាត។ បន្ទាប់ពីការដាក់ពិន័យនេះ ខ្សែប្រយុទ្ធក្រុម Paris Saint Germain មានរយៈពេល ២០ថ្ងៃសម្រាប់ប្តឹងឧទ្វរណ៍ផងដែរ។ រឿងហេតុរហូតធ្វើឱ្យ Neymar Jr ត្រូវបានអាជ្ញាធរផាកពិន័យ ដោយសារកាលពីថ្ងៃទី២២​ ខែមិថុនា បន្ទាប់ពីមានការបង្ហោះនៅលើបណ្តាញសង្គមនានា អាជ្ញាធរបានរកឃើញថាមានការបំផ្លាញបរិស្ថានធ្ងន់ធ្ងរនៅក្នុងដីផ្ទះដ៏ប្រណិតមួយកន្លែង ដែលមានក្រុមកម្មករបានកំពុងកសាងស្រះសិប្បនិមិត្ត ព្រមទាំងមានឆ្នេរខ្សាច់ថែមទៀត។ ក្រោយពេលរកឃើញ អាជ្ញាធរបានបិទទីតាំងសាងសង់នោះ និងបញ្ជាឱ្យបញ្ឈប់រាល់សកម្មភាពទាំងអស់ ប៉ុន្តែប្រព័ន្ធផ្សព្វផ្សាយប្រេស៊ីលបានរាយការណ៍ថា Neymar បានទៅធ្វើពិធីជប់លៀងនៅទីនោះ ហើយថែមទាំងងូតទឹកស្រះនោះថែមទៀត។ ដីផ្ទះវីឡាដ៏ធំស្គឹមស្កៃរបស់ Neymar ក្នុងទីក្រុង Mangaratiba ត្រូវបានអតីតសមាជិក Barcelona ទិញក្នុងឆ្នាំ ២០១៦ ហើយដីនោះមានទំហំប្រមាណ ១០,០០០ម៉ែត្រការ៉េ ដោយក្នុងនោះរួមមានទីតាំងចតឧទ្ធម្ភាគចក្រ ចំណែកក្នុងផ្ទះបំពាក់ដោយឧបរកណ៍ទំនើប ដូចជាបន្ទប់ស្ពា និងកន្លែងហាត់ប្រាណជាដើម៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  ព្រះរាជអាជ្ញាក្នុងប្រទេសប្រេស៊ីល បានដាក់ពិន័យតារាបាល់ទាត់ Neymar ជាទឹកប្រាក់ប្រមាណ ៣,៣ដុល្លារ ដោយសាររូបគេជីកស្រះនៅក្នុងបរិវេណដីផ្ទះរបស់ខ្លួន នៅប្រទេសកំណើតប្រេស៊ីល ដោយគ្មានសិទ្ធិអនុញ្ញាត ឬអាជ្ញាប័ណ្ណបរិស្ថាន។ នេះបើតាមសេចក្តីប្រកាសរបស់អាជ្ញាធរប្រេស៊ីលនៅថ្ងៃទី៣ ខែកក្កដា។
#
# Predicted Summary:
#  ខ្សែប្រយុទ្ធក្រុម Paris Saint Germain បានដាក់ទណ្ឌកម្មចំនួន ៤ សម្រាប់ការបំផ្លាញបរិស្ថានធ្ងន់ធ្ងរនៅក្នុងដីផ្ទះវីឡាដ៏ធំស្គឹមស្គៃរបស់ខ្សែប្រយុទ្ធក្រុម Paris Saint Germain ក្នុងទីក្រុង Rio។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0.0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 10 ---
# Full Article:
#  លោក មុំ ពិទូរ្យ លម្អិតព័ត៌មាននេះ ប៉ុន្មាន​ថ្ងៃមុន បេក្ខជន​បក្ស​សាធារណរដ្ឋ​និង​ជា​មហាសេដ្ឋី Donald Trump បាន​ថ្លែង​សុន្ទរកថា​បង្កប់​ភាព​រើសអើង​និង​ធ្វើ​ឲ្យ​ប៉ះពាល់​ដល់​អ្នក​កាន់សាសនា​ឥស្លាម ហើយ​មកដល់​ថ្ងៃអាទិត្យ​ម្សិលមិញ​បេក្ខជន​បក្ស​សាធារណរដ្ឋ​ម្នាក់ទៀត​បានលើកឡើង​ពី​បញ្ហា​សាសនា​ឥស្លាម​នេះ​ទៀត។ លោក Ben Carson ដែលជា​បេក្ខជន​ប្រធានាធិបតី​មកពី​បក្ស​សាធារណរដ្ឋ​បានផ្តល់​សុន្ទរកថា​មួយ បង្ក​ឲ្យ​សហគមន៍​អ្នក​កាន់សាសនា​ឥស្លាម​និង​សកម្មជន​ឯទៀត​ខឹងសម្បារ​ជាខ្លាំង​ដោយ​លោក​អះអាងថា​ប្រជាជន​មូស្លីម​មិនគួរ​ត្រូវគេ​បោះឆ្នោត​ឲ្យ​ក្លាយជា​ប្រធានាធិបតី​អាមេរិក​ឡើយ។ លោក​បាន​បន្តថា ការដែល​ជ្រើសរើស​ឲ្យ​អ្នក​កាន់សាសនា​ឥស្លាម​មកកាន់​តំណែង​ជា​ប្រធានាធិបតី​នេះ​វា​ផ្ទុយ​នឹង​រដ្ឋធម្មនុញ្ញ​អាមេរិក​ផង។ លោក​ថា៖ «ខ្ញុំ​មិន​គាំទ្រ​សោះ​ដែលថា​យើង​អនុញ្ញាត​ឲ្យ​អ្នក​កាន់សាសនា​ឥស្លាម​គ្រប់គ្រង​ប្រទេស។ ខ្ញុំ​ដាច់ខាត​មិន​ឯកភាព​ជាមួយ​ការធ្វើ​បែបនេះ​ទេ» យ៉ាងណាក៏ដោយ ទោះជា​បេក្ខជន​ប្រធានាធិបតី​ម្នាក់នេះ​លើកឡើង​ដូចជា​ទំនង​ណាស់​ក្តី លោក​មិនបាន​បញ្ជាក់​ច្បាស់​ពី​ចំណុច​ឬ​មាត្រា​ណាមួយ​ដែល​បញ្ជាក់ថា​សាសនា​ឥស្លាម​ផ្ទុយ​គោលការណ៍​រដ្ឋធម្មនុញ្ញ​អាមេរិក​នោះទេ។ លោក​បានត្រឹមតែ​លើកឡើង​ពី​បញ្ហា​នេះ ហើយ​អះអាង ថា វា​ជា​អំពើ​ប៉ះពាល់​ដល់​រដ្ឋធម្មនុញ្ញ​ប៉ុណ្ណោះ។ ក្រោយ​មានការ​ផ្តល់​សុន្ទរកថា​ធ្វើ​ឲ្យ​ប៉ះពាល់​ដល់​អ្នក​កាន់សាសនា​ឥស្លាម​នេះ ក្រុម​សកម្មជន​និង​តំណាង​សហគមន៍​អ្នក​កាន់សាសនា​ឥស្លាម​នៅ​អាមេរិក បានបង្ហាញ​ការខកចិត្ត​និង​ខឹងសម្បារ​ជាខ្លាំង។ ក្រុមប្រឹក្សា​ទំនាក់ទំនង​អាមេរិក​ឥស្លាម បានទាមទារ​ឲ្យ មាន​ការសុំ​អភ័យទោស និង​ដកសិទ្ធិ​បេក្ខជន​ម្នាក់នេះ​មិន​ឲ្យ​បន្ត​ប្រជែង​តំណែង​ប្រធានាធិបតី​ព្រោះថា​រដ្ឋធម្មនុញ្ញ​អាមេរិក​ហាម​ដាច់ខាត​មិន​ឲ្យ​យក​បញ្ហា​សាសនា​ជា​មធ្យោបាយ​សម្រាប់​ប្រជែង​យក​តំណែង​ណាមួយ​ក្នុង​ស្ថាប័ន​សាធារណ​ឡើយ។ ហើយ​សម្តី​នេះ​ក៏​ធ្វើ​ឲ្យ​ប៉ះពាល់​ដល់​អារម្មណ៍​បណ្តា​កងទ័ព​អាមេរិក​ដែលជា​អ្នកប្រតិបត្តិ​សាសនា​ឥស្លាម​ផងដែរ។ ដោយសារ​ពាក្យសម្តី​រើសអើង​សាសនា​នេះ បេក្ខជន​ប្រធានាធិបតី​ខាងលើ​អាច​ប្រឈមមុខ​នឹង​បញ្ហា​ច្រើន ជាពិសេស​បាត់បង់​សំឡេងគាំទ្រ​របស់ខ្លួន​ច្រើន។ សូមបញ្ជាក់​ផង​ថា លោក Carson ជា​បេក្ខជន​ម្នាក់​ក្នុងចំណោម​បេក្ខជន១៦នាក់​របស់​បក្ស ហើយ​លោក​ស្ថិតក្នុង​លេខ​រៀង​ទី៣នៃ​អ្នក​ដែល​ទទួលបាន​សំឡេងគាំទ្រ​ច្រើនជាងគេ។ អ្នក​ទី១គឺ​លោក Donald Trump លេខ​ពីរ​គឺ​សមាជិក​ព្រឹទ្ធសភា​លោក Lindsey Graham៕ លោក មុំ ពិទូរ្យ លម្អិតព័ត៌មាននេះ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  បេក្ខជន​ប្រ​ធានា​ធីប​តី​បក្ស​សាធារណរដ្ឋ​លោក Ben Carson បាន​អះអាងថា​អ្នក​កាន់សាសនា​ឥស្លាម​មិនគួរ​ត្រូវគេ​បោះឆ្នោត​ឲ្យ​កាន់តំណែង​ជា​ប្រធានាធិបតី​អាមេរិក​ឡើយ។ លោក​ថា​វា​ជា​រឿង​ដែល​ផ្ទុយ​រដ្ឋធម្មនុញ្ញ​អាមេរិក។ ប៉ុន្តែ​សម្តី​របស់​អ្នកនយោបាយ​រូបនេះ​កំពុង​ក្លាយជា​រឿងចម្រូងចម្រាស​ប៉ះពាល់​ដល់​សហគមន៍​អ្នក​កាន់សាសនា​ឥស្លាម​នៅ​សហរដ្ឋអាមេរិក ហើយ​វា​ក៏​ផ្ទុយ​នឹង​រដ្ឋធម្មនុញ្ញ​អាមេរិក​ដែល​មិន​និយាយ​ពី​បញ្ហា​សាសនា​ផងដែរ។
#
# Predicted Summary:
#  បេក្ខជន បក្ស សាធារណរដ្ឋ និង ជា មហាសេដ្ឋី Donald Trump បានផ្តល់ សុន្ទរកថា បង្កប់ ភាព រើសអើង និង ធ្វើ ឲ្យ សហគមន៍ អ្នក កាន់សាសនា ឥស្លាម ខឹងសម្បារ ជាខ្លាំង ក្រោយ មានការ ផ្តល់ សុន្ទរកថា បង្កប់ ភាព រើសអើង និង ធ្វើ ឲ្យ សហគមន៍ អ្នក កាន់សាសនា ឥស្លាម ខឹងសម្បារ ជាខ្លាំង។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0.0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 11 ---
# Full Article:
#  លទ្ធផល​ជា​ផ្លូវការ​ក្រោយ​ការបោះឆ្នោត​នៅក្នុង​ប្រទេស​អេ​ស្តូ​នី​បាន​បង្ហាញថា​គណបក្ស​កំណែទម្រង់​បានទទួល​សម្លេង​គា​ម​ទ្រ​ច្រើនជាងគេ។គណបក្ស​នេះ​កំពុង​ពិចារណា​ចាប់ដៃ​ជាមួយ​បណ្តា​គណបក្ស​ផ្សេងទៀត​ដើម្បី​បង្កើត​រដ្ឋាភិបាលចម្រុះ​ដែល​នឹងមាន​គណបក្ស​ចូលរួម​រហូតដល់៦គណបក្ស​ដែល​រដ្ឋាភិបាល​មុន​មាន​គណបក្ស​ចូលរួម​ត្រឹមតែ​បួន​ប៉ុណ្ណោះ។ គណបក្ស​កំណែទម្រង់​ដែល​ឈ្នះឆ្នោត​នេះ​ជា​គណបក្ស​ដែលមាន​ទំនោរ​ទៅរក​សហភាព​អឺរ៉ុប​និង​ជា​អ្នកគាំទ្រ​បក្សសម្ព័ន្ធ​យោធា​ណា​តូ​ផង​ហើយ​តាម​លទ្ធផល​ផ្លូវការ​គណបក្ស​នេះ​នេះ​ទទួលបាន​អាសនៈ៣០ក្នុងចំណោម​អាសនៈ​សរុប១។ប៉ុន្តែ​លទ្ធផល​បាន​បង្ហាញថា​គណបក្ស​នេះ​បាត់បង់​អាសនៈ​ចំនួន​បួន​ខណៈពេលដែល​គណបក្ស​កណ្តាល​និយម​ដែល​ទោរទន់​ទៅរក​រដ្ឋាភិបាល​ក្រេ​ម​ឡាំង​នោះ​កើន​បាន​មួយ​អាសនៈ​ពោល​គី​បាន២៧អាសនៈ។គណបក្ស​កណ្តាល​និយម​ទទួលបាន​គាំទ្រ​ច្រើន​ពី​សំណាក់​ប្រជាជន​ដែល​និយាយ​ភាសា​រុស្ស៊ី​មួយ​ភាគ​បួន​ក្នុងចំណោម១.៣លាន​នាក់។ ចំណែក​គណបក្ស​មួយទៀត​គឺ​គណបក្ស​សង្គម​ប្រជាធិបតេយ្យ​ឯណោះ​វិញ​បាន​អាសនៈ​ត្រឹម១៥តែប៉ុណ្ណោះ។យ៉ាងណាក៏ដោយ​ប្រធានាធិបតី​អេ​ស្តូ​នី​បច្ចុប្បន្ន​លោក​ToormasHendikIlvesនឹង​ស្នើ​សុំអោយ​មេដឹកនាំ​គណបក្ស​ជាប់ឆ្នោត​លោកនាយក​រដ្ឋមន្ត្រី​ផុត​អាណត្តិ​TaaviRoivasបង្កើត​រដ្ឋាភិបាលចម្រុះ​មួយ​ដើម្បី​ដោយ​សហការ​ជាមួយ​គណបក្ស​ផ្សេងទៀត​ដែលមាន​អាសនៈ​ក្នុង​សភា។ មន្ត្រី​ម្នាក់​បានអោយដឹងថា​គណ​បក្ស​កំណែទម្រង់​នឹង​បង្កើត​រដ្ឋាភិបាល​មួយ​ប៉ុន្តែ​បើ​និយាយ​ពី​ការបង្កើត​រដ្ឋាភិបាលចម្រុះ​វា​ហាក់បីដូចជា​រឿង​ស្មុ​គ្រ​ស្មាញ​មួយ។នេះ​មានន័យថា​គណបក្ស​ឈ្នះឆ្នោត​មិនមាន​ចេតនា​ក្នុង​ការបង្កើត​រដ្ឋាភិបាល​ចម្រុះ​នៅពេល​ខាងមុខ​នោះឡើយ។ក្រោយ​ការបោះឆ្នោត​នេះ​បង្ហាញថា​គណបក្ស​ដែលមាន​ជំហរ​គាំទ្រ​សហភាព​អឺរ៉ុប​និង​បក្សសម្ព័ន្ធ​យោធា​នៅតែមាន​ឥទ្ធិពល​ក្នុង​កិច្ចការ​នយោបាយ​ប្រទេស​អតីត​រដ្ឋ​សហភាពសូវៀត​នេះ​ប៉ុន្តែ​បញ្ហា​សន្តិសុខ​នៃ​រដ្ឋ​តំបន់​បាល់​ទិ​ក​នេះ​កំពុង​ស្ថិតក្នុង​ក្តីបារម្ភ​នៅឡើយ​ទេ។ មុន​មានការ​បោះឆ្នោត​គេ​ឃើញ​កងទ័ព​រុស្ស៊ី​ជាច្រើន​ពាន់​នាក់​នៅតាម​បណ្តោយ​ព្រំដែន​អេ​ស្តូ​នី​ដើម្បី​រៀបចំ​សមយុទ្ធ​យោធា​ដែល​សកម្មភាព​នេះ​បានធ្វើ​មេដឹកនាំ​រដ្ឋ​តំបន់​បាល់​ទិ​ក​ព្រួយ​ព្រួយបារម្ភ​ខ្លាំង។តាមពិតទៅ​បណ្តា​រដ្ឋ​ទាំងនោះ​ចាប់ផ្តើម​ភ័យព្រួយ​ចាប់តាំងពី​ពេលដែល​រុស្ស៊ី​ក្រសោប​យក​ដី​Crimeaកាលពី​ខែ​មិនា​ឆ្នាំមុន​មកម្ល៉េះ​ហើយ​គេ​រំពឹងថា​រុស្ស៊ី​អាច​នឹង​លូកដៃ​ក្នុង​បញ្ហានយោបាយ​អេ​ស្តូ​នី​និង​បង្ក​អស្ថិរភាព​នៅ​ទីនោះ​ថែម​ទៀតផង៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  គណ​ក្ស​ដែល​គាំទ្រ​បក្សសម្ព័ន្ធ​យោធា​ណា​តូ​បានទទួល​សម្លេងគាំទ្រ​ច្រើនសន្ធឹក​សន្ធាប់​នៅក្នុង​ការបោះឆ្នោត​កាលពី​ម្សិលមិញ​នៅ​អេ​ស្តូ​នី។គណបក្ស​កំណែទម្រង់​ដែល​បានទទួល​សម្លេងឆ្នោត​ច្រើន​នេះ​កំពុង​ពិចារណា​ពិភាក្សា​បង្កើត​រដ្ឋាភិបាល​ចម្រុះ​ដែល​នឹងមាន​គណបក្ស​ប្រហែល៦ឯណោះ​ចូលរួម​ដែល​វា​នឹងធ្វើ​អោយមាន​បញ្ហា​ប្រឈម​ខ្លាំង។
#
# Predicted Summary:
#  ប្រធានាធិបតី អេ ស្តូ នី លោក ToormasaHendikIlves នឹង ស្នើ អោយ មេដឹកនាំ គណបក្ស ជាប់ឆ្នោត លោកនាយក រដ្ឋមន្ត្រី ផុត អាណត្តិ TaaviRoivasបង្កើត រដ្ឋាភិបាលចម្រុះ មួយ ដើម្បី បង្កើត រដ្ឋាភិបាល ចម្រុះ មួយ ដែល នឹងមាន គណបក្ស ចូលរួម រហូតដល់៦គណបក្ស ដែល រដ្ឋាភិបាល មុន មាន គណបក្ស ចូលរួម ត្រឹមតែ បួន ប៉ុណ្ណោះ។ លទ្ធផល នេះ បង្ហាញថា គណបក្ស កំណែទម្រង់ ទទួលបាន សម្លេង គា ម ទ្រ ច្រើនជាងគេ។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 12 ---
# Full Article:
#  នៅថ្ងៃទី៨ ខែសីហា ក្រុមហ៊ុនផលិតបន្ទះឈីបតៃវ៉ាន់ TSMC បានយល់ព្រមលើកិច្ចព្រមព្រៀងតម្លៃ៣,៥ពាន់លានអឺរ៉ូ (៣,៨៣ ពាន់លានដុល្លារ) ដើម្បីសាងសង់រោងចក្រនៅអាល្លឺម៉ង់។ ការផ្លាស់ប្តូរនេះគឺជាផ្នែកមួយនៃកិច្ចខិតខំប្រឹងប្រែងដើម្បីធ្វើឱ្យអឺរ៉ុបក្លាយជាមជ្ឈមណ្ឌលនៃវិស័យសឺមីកុងឌុចទ័រពិភពលោក ។ អាម៉េរិក និងចិនកំពុងប្រកួតប្រជែងគ្នាយ៉ាងស្វិតស្វាញដើម្បីដណ្តើមភាពលេចធ្លោនៅក្នុង ឧស្សាហកម្មបន្ទះឈីប ហើយអឺរ៉ុបក៏កំពុងវិនិយោគរាប់ពាន់លានដុល្លារដើម្បីតាមទាន់ប្រទេសទាំងពីរនេះផងដែរ។ សឺមីកុងឌុចទ័រ ជាសមាសធាតុដែលមិនអាចខ្វះបាននៅក្នុងគ្រប់ឧបករណ៍អេឡិចត្រូនិក រាប់ចាប់ពីប្រដាប់ក្មេងលេង និងស្មាតហ្វូន ដល់រថយន្តអគ្គិសនី និងអាវុធទំនើបៗ។ ជំងឺកូវីដ-១៩ និងការបិទព្រំដែនជាបន្តបន្ទាប់ បានបណ្តាលឱ្យមានការខ្វះខាតបន្ទះឈីប និងធ្វើឱ្យវិស័យបច្ចេកវិទ្យាជាច្រើនត្រូវបញ្ឈប់នៅឆ្នាំ ២០២០ និង ២០២១។ វិបត្តិ​នេះ​បាន​ជំរុញ​ឱ្យ​អាម៉េរិក និង​ចិន​បាន​ចាត់វិធានការ​តឹងរ៉ឹង ​ដើម្បី​ធានា​ខ្សែច្រវាក់ផ្គត់ផ្គង់​បន្ទះសៀគ្វី។ ចំណែកអឺរ៉ុបកំពុងស្នើច្បាប់ដើម្បីជំរុញការវិនិយោគក្នុងវិស័យនេះ។ នៅក្នុងដំណើរការនៃការបញ្ចប់នីតិវិធីច្បាប់របស់សហភាពអឺរ៉ុប (EU) ពាក់ព័ន្ធបន្ទះឈីប មានគោលបំណងគៀងគរទុនប្រមាណ៤៣ពាន់លានអឺរ៉ូ (៤៩ពាន់លានដុល្លារ) ដើម្បីវិនិយោគពីវិស័យរដ្ឋ និងឯកជន។ ជាមួយនឹងផែនការនេះ សហភាពអឺរ៉ុបមានបំណងចាប់យកទីផ្សារ ២០ភាគរយនៃផលិតកម្មបន្ទះឈីបសកលនៅឆ្នាំ ២០៣០។ រហូតមកដល់ពេលនេះ អាឡឺម៉ង់នៅតែជាប្រទេសលេចធ្លោក្នុងការទាក់ទាញការវិនិយោគលើវិស័យបន្ទះឈីបនៅអឺរ៉ុប។ គម្រោងវិនិយោគពីក្រុមហ៊ុនតៃវាន់ TSMC នេះ ធ្វើឡើងបន្ទាប់ពីអាល្លឺម៉ង់បានរៀបចំកិច្ចព្រមព្រៀងជាមួយសាជីវកម្ម Intel ដើម្បីសាងសង់រោងចក្រដែលមានតម្លៃ ៣២ពាន់លានអឺរ៉ូកាលពីពីរខែមុន។ អាល្លឺម៉ង់ក៏បានទទួលកិច្ចព្រមព្រៀងដ៏ធំជាមួយក្រុមហ៊ុនអាម៉េរិក Wolfspeed និង Infineon នៅឆ្នាំនេះផងដែរ។ ស្ទើរតែទាំងអស់នៃវត្ថុធាតុដើមដែលត្រូវការដើម្បីផលិតបន្ទះឈីបត្រូវយកមកពីចិន។ តៃវ៉ាន់ដែលជាកន្លែងផលិតបន្ទះឈីបសំខាន់ៗមានច្រើនជាងពាក់កណ្តាលនៃការផលិតបន្ទះឈីបទូទាំងពិភពលោក ខណៈដែលក្រុមហ៊ុនរចនាបន្ទះឈីបល្បីៗដូចជា Nvidia និង Apple មកពីអាម៉េរិក។ សមាគមឧស្សាហកម្មសឺមីកុងឌុចទ័រដែលជាអង្គការពាណិជ្ជកម្មអាម៉េរិកបាននិយាយថា ក្រុមហ៊ុនអាម៉េរិកមានចំនួន ៤៨ភាគរយនៃវិស័យបន្ទះឈីបពិភពលោកកាលពីឆ្នាំមុន។ កូរ៉េខាងត្បូងដែលមានក្រុមហ៊ុនយក្ស Samsung ស្ថិតនៅលំដាប់ទីពីរ ជាមួយនឹងការរួមចំណែកបាន ១៤ភាគរយ។ ហើយ​អឺរ៉ុប​ស្ថិត​នៅ​លំដាប់​ទី​បី ​ដោយ​មាន​ចំណែក​ទីផ្សារ​៩ភាគរយ៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  ខណៈដែលអាម៉េរិក និងចិនកំពុងប្រកួតប្រជែងគ្នាយ៉ាងស្វិតស្វាញដើម្បីដណ្តើមទីផ្សារ នៅក្នុងវិស័យបន្ទះឈីប អឺរ៉ុបក៏កំពុងវិនិយោគទឹកប្រាក់តម្លៃរាប់ពាន់លានដុល្លារដើម្បីតាមឱ្យទាន់ប្រទេសទាំងពីរនេះ។ អាល្លឺម៉ង់ទើបទទួលបានការវិនិយោគពីក្រុមហ៊ុនតៃវ៉ាន់TSMC ចំនួន ៣,៨៣ពាន់លានដុល្លារដើម្បីផលិតបន្ទះឈីប។
#
# Predicted Summary:
#  ក្រុមហ៊ុនផលិតបន្ទះឈីបតៃវ៉ាន់ TSMC បានយល់ព្រមលើកិច្ចព្រមព្រៀងតម្លៃ៣,៥ពាន់លានអឺរ៉ូ (៣,៨៣ពាន់លានដុល្លារ) ដើម្បីសាងសង់រោងចក្រនៅអាល្លឺម៉ង់។
# ROUGE-1: 1.0
# ROUGE-2: 0.0
# ROUGE-L: 1.0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 13 ---
# Full Article:
#  តុលាការ​ធម្មនុញ្ញបាន​ធ្វើ​សេចក្តី​ប្រកាស​នេះ ​បន្ទាប់​ពី​ទទួល​យក​សម្រាប់​ការ​ពិចារណា​លើ​បណ្តឹង​មួយ​ ដែល​ពាក់​ព័ន្ធ​នឹង​ការ​កាន់កាប់​ភាគហ៊ុន​មរតក​របស់​លោក Pita នៅ​ក្នុង​ក្រុមហ៊ុន​ប្រព័ន្ធ​ផ្សព្វផ្សាយ iTV Plc។ រដ្ឋធម្មនុញ្ញ​ថៃ បានហាម​សមាជិក​សភា​មិន​ឱ្យ​កាន់​ភាគហ៊ុន ​ក្នុង​ស្ថាប័ន​សារព័ត៌មានទេ។ លោក Pita បានអះអាងថា ភាគហ៊ុនចំនួន ៤២ ០០០ភាគហ៊ុន ដែលជាផ្នែកមួយនៃទ្រព្យសម្បត្តិរបស់ឪពុកចុង។ លោក​បន្ត​ថា ប័ណ្ណ​កម្មសិទ្ធិ​នេះ​ ត្រូវ​បាន​ផ្ទេរ​ទៅ​ឲ្យ​សាច់​ញាតិ​តាំង​ពី​ពេល​នោះ​មក។ ការព្យួរឈ្មោះពីសមាជិកសភានេះ មិនបានរារាំងបេក្ខភាព លោក​ Pita ជានាយករដ្ឋមន្ត្រីនោះទេ។ ប៉ុន្តែវាទំនងក្លាយជាហេតុផលមួយទៀត ដែលធ្វើឱ្យលោក Pita ជួបការលំបាក។ លើសពីនេះ ​តុលាការព្យួរ​ឈ្មោះ លោក Pita ​ពី​កាតព្វកិច្ច​សមាជិក​សភា​ដោយ​រង់ចាំ​ការ​នីតិវិធីជាបន្តផងដែរ ដោយសំឡេងប្រាំពីរ ទល់នឹងពីរ។ តុលាការបានបញ្ជាឱ្យ លោក Pita ដាក់ការពន្យល់ក្នុងរយៈពេល ១៥ ថ្ងៃ បន្ទាប់ពីទទួលបានច្បាប់ចម្លងនៃសេចក្តីសម្រេចនេះ៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  នៅព្រឹកថ្ងៃទី ១៩ ខែ កក្កដា តុលាការធម្មនុញ្ញថៃ បានព្យួរមេដឹកនាំគណបក្សឆ្ពោះទៅមុខ ដែលជាបេក្ខជននាយករដ្ឋមន្ត្រី លោក Pita Limjaroenrat ពីតួនាទីជាសមាជិកសភាតំណាងរាស្រ្ត។
#
# Predicted Summary:
#  រដ្ឋាភិបាល ថៃ បាន ព្យួរ ឈ្មោះ លោក Pita ពី កាតព្វកិច្ច សមាជិក សភា ដែល ពាក់ ព័ន្ធ នឹង ការ កាន់កាប់ ភាគហ៊ុន មរតក របស់ លោក Pita នៅ ក្នុង ក្រុមហ៊ុន ប្រព័ន្ធ ផ្សព្វផ្សាយ iTV Plc។ តុលាការធម្មនុញ្ញថៃ បានហាម សមាជិក សភា មិន ឱ្យ កាន់កាប់ ភាគហ៊ុន ក្នុង ក្រុមហ៊ុន ប្រព័ន្ធ ផ្សព្វផ្សាយ iTV Plc។
# ROUGE-1: 0.25
# ROUGE-2: 0.0
# ROUGE-L: 0.25
# ----------------------------------------------------------------------------------------------------
#
# --- Article 14 ---
# Full Article:
#  ​តាមរយៈ​សុន្ទរកថា​បើក​កិច្ចប្រជុំ​រដ្ឋមន្ត្រី​សេដ្ឋកិច្ច​អាស៊ាន​លើក​ទី​៥១ ក្នុង​រាជធានី​បាងកក លោកនាយក​រដ្ឋមន្ត្រី ប្រា​យុទ្ធ ចន្ទ អូ​ចា បាន​ថ្លែង​ទៅកាន់​រដ្ឋមន្ត្រី​អាស៊ាន​ទាំង​ដប់ និង​ដៃគូ​សន្ទនា​ទាំង​ប្រាំមួយ​ត្រូវតែ​ធ្វើការ​ជាមួយគ្នា​ដើម្បី​កសាង​ការតភ្ជាប់​ទាំង​ក្នុង និង​ក្រៅ ក្នុង​គោលដៅ​បញ្ចប់​ការចរចា​កិច្ចព្រមព្រៀង​ពាណិជ្ជកម្ម​ភាពជា​ដៃគូ​គ្រប់​ជ្រុងជ្រោយ​ក្នុង​តំបន់​ឲ្យ​បាន​ចប់​នៅត្រឹម​ឆ្នាំនេះ​។​ ​លោកនាយ​រដ្ឋមន្ត្រី តាម​ការចុះផ្សាយ​របស់​សារព័ត៌មាន Bangkok បាន​លើកឡើងថា ការ​ព​ន្លឿ​ន​ការបញ្ចប់​ការចរចា​រវាង​ភាគី​ពាក់ព័ន្ធ នឹង​ឆ្លុះបញ្ចាំង​ឲ្យ​ឃើញ​ពី​ការទុកចិត្ត​គ្នា​ក្នុងចំណោម​ដៃគូ​ក្នុង​ការកសាង​ប្រព័ន្ធ​ពាណិជ្ជកម្ម និង​វិនិយោគ​រួមគ្នា​ក៏ដូចជា​បទដ្ឋាន ក្នុងការ​គ្រប់គ្រង​ពាណិជ្ជកម្ម​ពហុភាគី​។​ ​ គួរ​ឲ្យ​សម្គាល់​នោះ ក្នុងជំនួប​ចុងក្រោយ​នៅ​ខែមិថុនា​កន្លងទៅ អាស៊ាន និង​ដៃគូ​សន្ទនា​របស់ខ្លួន បាន​ឯកភាពគ្នា​លើ​៧​ជំពូក នៃ​ជំពូក​សរុប​ទាំង​២០ របស់ RCEP ដែល​នេះ​មានន័យថា មុនពេល​ជំនួប​កំពូល​របស់​អាស៊ាន​នា​ខែវិច្ឆិកា​ខាងមុខនេះ រដ្ឋ​ភាគី ត្រូវ​ព​ន្លឿ​ន​ការចរចា​លើ​ចំណុច​ដែល​សេសសល់​ឲ្យ​បាន​ឆាប់​។ ​ ក្នុងនាម​ជា​ម្ចាស់ផ្ទះ និង​ជា​ស្ថាបនិក​របស់​អាស៊ាន​ផង​នោះ ប្រមុខ​ដឹកនាំ​ថៃ​រូបនេះ បាន​អះអាងថា អាស៊ាន បានកកើតឡើង​ជាមួយ​នឹង​ក្តី​ស្រ​ម៉ៃ និង​ចក្ខុវិស័យ ចង់ឃើញ​តំបន់​មាន​ភាពរុងរឿង​តាមរយៈ​ស្ថិរភាព​នយោបាយ កំណើនសេដ្ឋកិច្ច និង​ការអភិវឌ្ឍ​សង្គម​។ ​ គួរ​ជម្រាប​ថា អាស៊ាន ដែលមាន​រាជាណាចក្រ​ថៃ ជា​ប្រធាន​វិលជុំ បានរៀបចំ​កិច្ចប្រជុំ​រដ្ឋមន្ត្រី​សេដ្ឋកិច្ច​អាស៊ាន ( AEM) ដែល​ត្រូវ​ចាប់ផ្តើម​ពីថ្ងៃ​៨-១២ កញ្ញា​។ ជំនួប​នេះ ផ្តោតលើ​មាគ៌ា​ដែល​អាស៊ាន​ត្រូវ​ដើរ​ក្នុង​ដំណើរ​សមាហរណកម្ម​សេដ្ឋកិច្ច និង​ជាពិសេស​នោះ​លើ​ដំណើរ​ការចរចា​កិច្ចព្រមព្រៀង​ពាណិជ្ជកម្ម​សេរី RCEP​។​ RCEP គឺជា​កិច្ចព្រមព្រៀង​ពាណិជ្ជកម្ម​មួយ​ដែល​ផ្តួចផ្តើម​ដោយ​រដ្ឋាភិបាល​ចិន​ក្នុង​ឆ្នាំ​២០១២​។ កិច្ចព្រមព្រៀង​ដែលមាន​ទំហំ​ពាណិជ្ជកម្ម​ស្មើនឹង​៣០​ភាគរយ នៃ​ផលិតផល​ក្នុងស្រុក​សរុប​របស់​ពិភពលោក បង្កើតឡើង​ដើម្បី​ប្រែក្លាយ​តំបន់​រដ្ឋ​អាស៊ាន និង​ដៃគូ​សន្ទនា​របស់ខ្លួន​ក្លាយជា​តំបន់​ពាណិជ្ជកម្ម​សេរី ខណៈ​ពិភពលោក លើកកម្ពស់​សាកលភាវូបនីយកម្ម​។ ​ ភាគី​នៃ​កិច្ចព្រមព្រៀង​នេះ រាប់បញ្ចូល​សមាជិក​អាស៊ាន​ទាំង​ដប់ និង ដៃគូ​សន្ទនា​ផ្សេងទៀត​រួមមាន​ចិន ជប៉ុន កូរ៉េខាងត្បូង ឥណ្ឌា អូស្ត្រាលី និង ណូ​វែ​ល​សេ​ឡង់​។ តាមពិតទៅ RCEP គ្រោង​នឹង​បញ្ចប់​ការ​ព្រមព្រៀងគ្នា​តាំងពី​ឆ្នាំ ២០១៥ ប៉ុន្តែ​ត្រូវ​បន្ត​ពន្យារពេល​ជា​បន្តបន្ទាប់​រហូតមក​ទល់​ពេលនេះ​។ អាស៊ាន និង​ដៃគូ បាន​ប្តេជ្ញា​សម្រេច​ការចរចា​ឲ្យ​បាន​ត្រឹម​បំណាច់​ចុងឆ្នាំ​នេះ ខណៈ​អាស៊ាន​ដែលមាន​ថៃ​ជា​ប្រធាន នឹងមាន​ជំនួប​កំពូល​មួយទៀត នៅ​ខែវិច្ឆិកា​ខាងមុខ​៕ ​ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  ប្រមុខ​រដ្ឋាភិបាល​ថៃ លោក ប្រា​យុទ្ធ ចន្ទ អូ​ចា បាន​ទទូច​ឲ្យ​អាស៊ាន និង​ដៃគូ​សន្ទនា​របស់ខ្លួន​ព​ន្លឿ​ន​ការចរចា​លើ​លក្ខខណ្ឌ​នៃ​កិច្ចព្រមព្រៀង​ពាណិជ្ជកម្ម​ភាពជា​ដៃគូ​គ្រប់​ជ្រុងជ្រោយ​ក្នុង​តំបន់ ( RCEP) ឲ្យ​បាន​ចប់សព្វគ្រប់​ត្រឹម​បំណាច់​ខែវិច្ឆិកា​។ ប្រមុខ​ដឹកនាំ​ថៃ​រូបនេះ មើលឃើញថា ដំណើរការ​នៃ​ការចរចា​កិច្ចព្រមព្រៀង​ល្មម​នឹងត្រូវ​បញ្ចប់​ហើយ​។
#
# Predicted Summary:
#  កិច្ចប្រជុំ រដ្ឋមន្ត្រី សេដ្ឋកិច្ច អាស៊ាន លើក ទី ៥១ ក្នុង រាជធានី បាងកក បាន បើក កិច្ចប្រជុំ រដ្ឋមន្ត្រី សេដ្ឋកិច្ច អាស៊ាន លើក ទី ៥១ ក្នុង រាជធានី បាងកក ដើម្បី បញ្ចប់ ការចរចា កិច្ចព្រមព្រៀង ពាណិជ្ជកម្ម ភាពជា ដៃគូ គ្រប់ ជ្រុងជ្រោយ ក្នុង តំបន់ ឲ្យ បាន ចប់ នៅត្រឹម ឆ្នាំ ២០២៤ ។ កិច្ចប្រជុំ នេះ ផ្តោតលើ មាគ៌ា ដែល អាស៊ាន ត្រូវ ព ន្លឿ ន ការចរចា លើ ចំណុច ដែល សេសសល់ ឲ្យ បាន ឆាប់ ។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 15 ---
# Full Article:
#  ចំណាត់ការទាំងពីរប្រទេសខាងលើនេះ កើតឡើងត្រឹមតែមួយសប្តាហ៍បន្ទាប់ពីឥណ្ឌាដែលជាប្រទេសនាំចេញអង្ករធំជាងគេរបស់ពិភពលោក សម្រេចបញ្ឈប់ការនាំចេញអង្ករដែលមិនមែនជាប្រភេទ Basmati (អង្ករពេញនិយមនៅអាស៊ីខាងត្បូង)។ ការនាំចេញនឹងត្រូវបានធ្វើឡើងទៅបាន លុះត្រាតែមានការអនុញ្ញាតពីអាជ្ញាធរឥណ្ឌា តាមសំណើរបស់រដ្ឋាភិបាលមួយផ្សេងទៀត ដើម្បីធានាសន្តិសុខស្បៀងនៅក្នុងប្រទេសនោះ។ រដ្ឋាភិបាល​ឥណ្ឌា​និយាយ​ថា ការ​សម្រេច​ចិត្ត​នេះ​នឹង​ប៉ះ​ពាល់​ដល់ ២៥ភាគរយនៃ​ការ​នាំ​ចេញ​អង្ករ​សរុប​របស់​ខ្លួន។ ការផ្លាស់ប្តូរនេះ បានកើតឡើងនៅក្នុងបរិបទនៃការរំខាននៃខ្សែច្រវាក់ផ្គត់ផ្គង់ពិភពលោក និងសម្ពាធអតិផរណាដែលកំពុងអង្រួនសេដ្ឋកិច្ចប្រទេសជាច្រើន។ ដូច្នេះ ប្រទេសនានាត្រូវតែចាត់វិធានការយ៉ាងសកម្ម ដើម្បីធានាសន្តិសុខស្បៀង និងការពារទីផ្សារក្នុងស្រុកពីការប្រែប្រួលតម្លៃ។ ទឹកជំនន់ និងគ្រោះរាំងស្ងួតដែលបណ្តាលមកពីបាតុភូត El Nino កំពុងគំរាមកំហែងដល់ដំណាំនៅឥណ្ឌា និងថៃដែលជាប្រទេសនាំចេញអង្ករធំជាងគេទីពីរ។ ភាព​តានតឹង​រវាង​រុ​ស្ស៊ី និង​អ៊ុយ​ក្រែ​ន​ក៏​បាន​បណ្តាល​ឱ្យ​តម្លៃ​គ្រាប់​ធញ្ញជាតិ​ជា​ច្រើន​ទៀត​ឡើង​ថ្លៃ​ផង​ដែរ ។ សារព័ត៌មានរ៉យទ័របានរាយការណ៍ថា នៅអាស៊ីតម្លៃអង្ករបាក់របស់ថៃបានកើនឡើង ១៥ភាគរយក្នុងរយៈពេល ៤ខែចុងក្រោយនេះដល់ ៥៣៥ដុល្លារក្នុងមួយតោន។ នេះគឺជាកម្រិតខ្ពស់បំផុតចាប់តាំងពីខែមីនា ឆ្នាំ២០២១។ ចំណែកអង្ករបាក់របស់វៀតណាមក៏បានកើនឡើងដល់ចន្លោះ ៥១៥ ទៅ ៥២៥ដុល្លារក្នុងមួយតោនផងដែរក្នុងខែនេះ ដែលជាចំនួនខ្ពស់បំផុតចាប់តាំងពីឆ្នាំ២០១១ ។ ទន្ទឹម​នឹង​នេះ នៅ​ឥណ្ឌាតម្លៃ​អង្ករ​លក់​រាយ​នៅ​ក្រុង​ដេលី​បាន​កើន​ឡើង ១៥ភាគរយនៅ​ឆ្នាំ​នេះ។ យោង​តាម​ទិន្នន័យ​ពី​ក្រសួង​ឧស្សាហកម្មកែច្នៃ​អាហារ​របស់​ឥណ្ឌា​ តម្លៃ​មធ្យមនៅក្នុងប្រទេស​បាន​កើន​ឡើង ៨ ភាគរយ។ ដូច្នេះ ឥណ្ឌា​ត្រូវ​កំណត់កូតា​ការ​លក់​អង្ករ​ទៅអន្តរជាតិដើម្បី​បន្ថយ​តម្លៃ​ក្នុង​ស្រុក និង​គ្រប់គ្រង​អតិផរណា។ កាល​ពី​ខែ​មុន សន្ទស្សន៍​តម្លៃ​ទំនិញ​ប្រើ​ប្រាស់ (CPI) របស់​ឥណ្ឌា ​បាន​កើន​ឡើងជា​ចម្បង​ដោយ​សារ​តម្លៃ​ម្ហូប​អាហារ​ខ្ពស់។ ចំណែក អេមីរ៉ាតអារ៉ាប់រួមជាប្រទេសនាំចូលអាហាររហូតដល់ ៩០ភាគរយក្នុងមួយឆ្នាំៗ។ ពួកគេ​ទិញ​អង្ករ​ជា​ចម្បង​ពី​​ឥណ្ឌា ប៉ាគីស្ថាន វៀតណាម និង​ថៃ។ យោងតាមក្រសួងសេដ្ឋកិច្ចរបស់អេមីរ៉ាតអារ៉ាប់រួម ការហាមឃាត់បណ្តោះអាសន្ននេះមានគោលបំណងធានាការផ្គត់ផ្គង់ក្នុងស្រុក ក្រោយពីឥណ្ឌាបានហាមឃាត់ការនាំចេញអង្ករ។ អតិផរណាក៏អាចនៅពីក្រោយការសម្រេចចិត្តរបស់អេមីរ៉ាតអារ៉ាប់រួមផងដែរ។ អ្នកលក់រាយនៅទីនេះព្យាករថា ការហាមឃាត់របស់ឥណ្ឌានឹងធ្វើឱ្យតម្លៃអង្ករក្នុងស្រុកកើនឡើង ៤០ភាគរយ។ កាល​ពី​ឆ្នាំ​មុន ការ​ឡើង​ថ្លៃ​ម្ហូប​អាហារ​បាន​ដាក់​សម្ពាធ​លើ​ប្រទេស​ឈូង​សមុទ្រមួយនេះយ៉ាងខ្លាំង។ ដោយឡែក​រុស្ស៊ី​ រដ្ឋាភិបាលបាននិយាយ​ថា គោល​បំណង​របស់​ខ្លួន​គឺ​ធ្វើ​ឲ្យ​ទីផ្សារ​ក្នុង​ស្រុក​មាន​ស្ថិរភាព។ រុស្ស៊ី​មិន​មែន​ជា​ប្រទេស​នាំ​ចេញ​ដ៏​សំខាន់​ក្នុង​ពិភពលោក​ ប៉ុន្តែពួកគេដាំស្រូវ និងជាអ្នកផ្គត់ផ្គង់អង្ករ Japonica ដ៏សំខាន់ទៅកាន់ប្រទេសជិតខាងដូចជាអាស៊ែបៃហ្សង់និងហ្សកហ្ស៊ី។ ពួកគេក៏លក់អង្ករទៅប្រទេសតួកគី អេហ្ស៊ីប និងហ្ស៊កដានីផងដែរ។ នេះបើយោងតាមទិន្នន័យរបស់ S&P Global ។ នេះ​មិន​មែន​ជា​លើក​ទី​មួយ​ទេ​ដែល​រុស្ស៊ី​ហាម​ឃាត់​ការ​នាំ​ចេញ​អាហារ។ ជាក់ស្តែងនៅក្នុងខែកក្កដា ឆ្នាំ២០២២ ក្រសួងកសិកម្មរុស្ស៊ីបានសម្រេចចិត្តហាមឃាត់ការនាំចេញអង្ករ គ្រាប់ធញ្ញជាតិ និងអាស៊ីតអាមីណូដែលប្រើប្រាស់ក្នុងចំណីសត្វរហូតដល់ដំណាច់ឆ្នាំ។ មន្ត្រីរុស្ស៊ីបានពន្យល់ថា ពួកគេត្រូវការធានាសន្តិសុខស្បៀងនៅក្នុងប្រទេស រក្សាស្ថិរភាពតម្លៃក្នុងស្រុកនៃផលិតផលទាំងនេះ ក៏ដូចជាគាំទ្រដល់ឧស្សាហកម្មកែច្នៃ និងបសុសត្វ។ បន្ទាប់ពីនោះ ការបញ្ជាទិញត្រូវបានបន្តរហូតដល់ចុងខែមិថុនា ឆ្នាំ២០២៣ ហើយបច្ចុប្បន្នបន្តរហូតដល់ដំណាច់ឆ្នាំនេះ។ អ្នក​វិភាគ​និយាយ​ថា ប្រទេស​នានា​មាន​ទំនោរ​កាន់​តែ​ខ្លាំង​ឡើង​ក្នុង​ការ​ផ្តល់​អាទិភាព​ដល់​តម្រូវ​ការ​ក្នុង​ស្រុក​ក្នុង​បរិបទ​អស្ថិរភាព​សេដ្ឋកិច្ច​ពិភពលោក។ ប្រទេសជាច្រើនកំពុងអនុវត្តវិធានការផ្សេងៗដើម្បីការពារផលិតផលក្នុងស្រុក និងអ្នកប្រើប្រាស់ពីផលប៉ះពាល់ជាសកល។ នៅពេលដែលសេដ្ឋកិច្ចពិភពលោកនៅតែបន្តមិនអាចទាយទុកជាមុនបាន វិធានការទាំងនេះត្រូវបានគេរំពឹងថានឹងកាន់តែរីករាលដាល និងបង្កឱ្យមានផលវិបាកកាន់តែច្រើន។ របប​គាំពារ​អាហារ​បាន​លេច​ឡើង​កាល​ពី​ឆ្នាំ​មុន។ រហូតមកដល់ពេលនេះ ប្រទេសរាប់សិបបានរឹតបន្តឹងការនាំចេញអាហារជាការឆ្លើយតបនឹងការកើនឡើងតម្លៃដែលបណ្តាលមកពីភាពតានតឹងនៅអ៊ុយក្រែន។ ឥណ្ឌាដាក់កម្រិតលើការនាំចេញស្រូវសាលី និងស្ករ។ ឥណ្ឌូណេស៊ី ដាក់កម្រិតលើការលក់ប្រេងដូង។ ម៉ាឡេស៊ី ហាមឃាត់ការនាំចេញសាច់មាន់ ឯប្រទេសជាច្រើនទៀតក៏ដាក់កូតាលើធញ្ញជាតិផងដែរ។ បើតាមសារព័ត៌មានជប៉ុន Nikkei លោក Sabrin Chowdhury ប្រធានផ្នែកទំនិញនៅ Fitch Solutions បាននិយាយថា នេះនឹងបង្កើនហានិភ័យសន្តិសុខស្បៀងសម្រាប់ក្រុមដែលងាយរងគ្រោះបំផុត។ ការកើនឡើងនៃរបបគាំពារអាហារនៅពេលនេះអាចបណ្តា ...
#
# Reference Summary:
#  នៅថ្ងៃទី២៩ ខែកក្កដា រដ្ឋាភិបាលរុស្ស៊ីបានប្រកាសហាមឃាត់ការនាំចេញអង្កររហូតដល់ដំណាច់ឆ្នាំនេះ។ ករណីនេះមានការលើកលែងចំពោះសហភាពសេដ្ឋកិច្ចអឺរ៉ាស៊ីក៏ដូចជា Abkhazia និង South Ossetia ហើយខ្លួននៅ​តែ​អាច​បញ្ជូន​អង្ករ​ទៅ​ក្រៅ​ប្រទេសបាន​ក្នុង​គោល​បំណង​មនុស្សធម៌។ មួយ​ថ្ងៃ​មុន​នេះ ក្រសួង​សេដ្ឋកិច្ច​​អេមីរ៉ាត​អារ៉ាប់រួមបាន​សម្រេចបញ្ឈប់​ការ​នាំ​ចេញ​អង្ករ ​រយៈពេល ៤ ខែ។ បទប្បញ្ញត្តិនេះចូលជាធរមានភ្លាមៗ អនុវត្តចំពោះអង្ករគ្រប់ប្រភេទ។
#
# Predicted Summary:
#  ឥណ្ឌាបានសម្រេចបញ្ឈប់ការនាំចេញអង្ករដែលមិនមែនជាប្រភេទBasmati (អង្ករពេញនិយមនៅអាស៊ីខាងត្បូង) ក្នុងរយៈពេល ៤ខែចុងក្រោយនេះ។ ចំណាត់ការទាំងពីរប្រទេសនេះ កើតឡើងបន្ទាប់ពីឥណ្ឌាបានសម្រេចបញ្ឈប់ការនាំចេញអង្ករដែលមិនមែនជាប្រភេទBasmati។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0.0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 16 ---
# Full Article:
#  ​កាលពីថ្ងៃទី២៩ ខែកុម្ភៈ សហព័ន្ធបាល់ទាត់អារ៉ាប៊ីសាអូឌីត (SAFF) បានដាក់ពិន័យលើ Ronaldo មិនឱ្យចូលលេងចំនួន ១ប្រកួត ព្រោះតែការបង្ហាញកាយវិការអាសអាភាសទល់អ្នកគាំទ្រក្រុម Al Shabab កាលពីសប្តាហ៍មុន។ បញ្ហាបានកើតឡើងនៅពេល អ្នកគាំទ្រក្រុម Al Shabab ស្រែកចម្អកដោយប្រើពាក្យអតីតគូប្រជែង Lionel Messi ហើយកីឡាករវ័យ ៣៩ឆ្នាំ ក៏ឆ្លើយតបដោយកាយវិការមិនសមរម្យត្រឡប់ទៅវិញ។ លើរឿងហេតុនេះ តារាបាល់ទាត់ព័រទុយហ្កាល់ ត្រូវបានសហព័ន្ធ SAFF ពិន័យជាប្រាក់បន្ថែមជាង ៨ពាន់ដុល្លារ បូករួមទាំងសំណងទៅក្លិប Al Shabab។ ដោយឡែកនៅក្នុងការប្រកួតដែល Al Nassr បានត្រឹមស្មើជាមួយនឹងក្រុមភ្ញៀវ Al Hazm លទ្ធផល ៤-៤ ក្នុងជំនួបក្របខណ្ឌ Saudi Pro League នាថ្ងៃទី២៩ ខែកុម្ភៈ Ronaldo បានត្រឹមអង្គុយមើលការប្រកួតពីចម្ងាយប៉ុណ្ណោះ។ អ្នកគាំទ្រ Al Nassr បាននាំគ្នាស្រែកឈ្មោះ តារាបាល់ទាត់វ័យចំណាស់នៅត្រឹមនាទី៧ ខណៈម្ចាស់ពាន Ballon d’Or ៥សម័យ បានឆ្លើយតបដោយការលើកដៃជាកម្លាំងចិត្តទៅកាន់អ្នកគាំទ្រវិញ។ ទោះគ្មានវត្តមាន Ronaldo ប៉ុន្តែ Al Nassr នៅតែជាក្រុមខ្លាំងមួយនៅក្នុងការប្រកួត ខណៈដែលកីឡាករខ្សែប្រយុទ្ធ Anderson Talisca រកបានគ្រាប់បាល់ ៣គ្រាប់ម្នាក់ឯង ហើយគ្រាប់ទី៤ ធ្វើបានដោយខ្សែប្រយុទ្ធសេណេហ្គាល់ Sadio Mane ដោយការស៊ុតបាល់ពិន័យ ១១ម៉ែត្រ។ ក្រុមភ្ញៀវ Al Hazm ក៏មិនបណ្តោយឱកាសរបូតពិន្ទុដោយព្យាយាមស៊ុតបាល់តាមស្មើមកវិញ ៤គ្រាប់ដោយកីឡាករ Ahmad Al Mhemaid, Paulo Ricardo, Toze និងកីឡាករ Faiz Selemani៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  អ្នកគាំទ្រក្រុម Al Nassr ស្រែកហៅឈ្មោះខ្សែប្រយុទ្ធ Cristiano Ronaldo ពេញកីឡដ្ឋាន ខណៈកីឡាករព័រទុយហ្កាល់ត្រូវបានគេឃើញអង្គុយមើលការប្រកួតដែលក្រុមពួកគេស្មើ Al Hazm លទ្ធផល ៤-៤។  ប្រធានក្រុមវ័យ ៣៩ឆ្នាំ ដែលជាប់បម្រាមមួយប្រកួត ចំពោះកាយវិការអាសអាភាសកាស បានលើកដៃបង្ហាញសញ្ហាឆ្លើយតបទៅអ្នកគាំទ្រដែលបានស្រែកហៅឈ្មោះខ្លួន។
#
# Predicted Summary:
#  Cristiano Ronaldo ត្រូវបានសហព័ន្ធបាល់ទាត់អារ៉ាប៊ីសាអូឌីត (SAFF) ដាក់ពិន័យលើ Cristiano Ronaldo មិនឱ្យចូលលេងចំនួន ១ប្រកួត ក្នុងជំនួបក្របខណ្ឌ Saudi Pro League នាថ្ងៃទី២៩ ខែកុម្ភៈ។
# ROUGE-1: 0.2857
# ROUGE-2: 0.1667
# ROUGE-L: 0.2857
# ----------------------------------------------------------------------------------------------------
#
# --- Article 17 ---
# Full Article:
#  ក្នុងឆ្នាំ២០២១ អង្គការកម្មសិទ្ធិបញ្ញាពិភពលោក (WIPO) បានរកឃើញថា ការច្នៃប្រឌិតថ្មីនៅតែមានសន្ទុះនៅក្នុងប្រទេសមួយចំនួន ទោះបីសេដ្ឋកិច្ចពិភពលោកកំពុងធ្លាក់ចុះដោយសារការរីករាលដាលនៃជំងឺកូវីដ-១៩ ក៏ដោយ។ ប្រទេសដែលមានគំនិតច្នៃប្រឌិតថ្មីខ្ពស់បំផុតប្រចាំឆ្នាំ ២០២១ គឺស៊្វីស។ ស៊្វីសបានឈរនៅកំពូលតារាងដោយទទួលបានពិន្ទុ ៦៥,៥ លើ ១០០។ នេះជាលើកទី១១ហើយ ដែលប្រទេសនេះបានជាប់ឈ្មោះជាមេដឹកនាំពិភពលោកក្នុងការអភិវឌ្ឍគំនិតច្នៃប្រឌិត។ តារាងចំណាត់ថ្នាក់នេះ ត្រូវបានបង្កើតឡើងដើម្បីប្រៀបធៀបពីកម្រិតច្នៃប្រឌិតថ្មីក្នុងប្រទេសចំនួន ១៣០ ដោយឆ្លងកាត់ការវាយតម្លៃលើវិស័យមួយចំនួន ដូចជា ធនធានមនុស្សចេះដឹង បច្ចេកវិទ្យា ការកែច្នៃ ក៏ដូចជាផ្នែកទីផ្សារ និងអាជីវកម្មផងដែរ។ តាមការចុះផ្សាយលើទំព័រ WIPO ប្រទេសចំនួន ១០ដែលស្ថិតនៅលំដាប់កំពូលតារាងនៃប្រទេសមានគំនិតច្នៃប្រឌិតថ្មីប្រចាំឆ្នាំ ២០២១ មានដូចជា៖ ១. ស៊្វីស ២. ស៊ុយអែត ៣. អាម៉េរិក ៤. អង់គ្លេស ៥. កូរ៉េខាងត្បូង ៦. ហូឡង់ ៧. ហ្វាំងឡង់ ៨. សិង្ហបុរី ៩. ដាណឺម៉ាក ១០. អាល្លឺម៉ង់ គួរបញ្ជាក់ថា ប្រទេសដែលមានការអភិវឌ្ឍការច្នៃប្រឌិតលឿនគួរឱ្យកត់សម្គាល់គឺ កូរ៉េខាងត្បូង ព្រោះកាលពីឆ្នាំ ២០២០ ប្រទេសនេះបានឈរនៅលំដាប់ពី១០ឯណោះ។ ចំណែក ចិនបានស្ថិតនៅលំដាប់ទី១២ ខណៈឆ្នាំ២០២០ស្ថិតនៅលំដាប់ទី១៤។ ជប៉ុន ក៏បានទទួលលទ្ធផលល្អផងដែរ ដោយស្ថិតនៅលំដាប់ទី១៣ ក្រោយធ្លាក់ពីលំដាប់ទី១៦ក្នុងឆ្នាំ២០២០៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  អង្គការកម្មសិទ្ធិបញ្ញាពិភពលោក (WIPO) ក្នុងខែកញ្ញា បានចេញតារាងបែងចែកលំដាប់ថ្នាក់ប្រទេស ដែលមានគំនិតច្នៃប្រឌិតថ្មីខ្លាំងជាងគេប្រចាំឆ្នាំ ២០២១។ ស៊្វីសជាប្រទេសឈរនៅលេខរៀងទី១ ជាមួយលំដាប់ពិន្ទុ៦៥,៥ លើ ១០០។
#
# Predicted Summary:
#  លោក ស៊្វីស បានជាប់ឈ្មោះជាមេដឹកនាំពិភពលោកក្នុងការអភិវឌ្ឍគំនិតច្នៃប្រឌិតថ្មីប្រចាំឆ្នាំ ២០២១ ដោយទទួលបានពិន្ទុ ៦៥,៥ លើ ១០០។ នេះបើតាមការចុះផ្សាយរបស់អង្គការកម្មសិទ្ធិបញ្ញាពិភពលោក (WIPO)។
# ROUGE-1: 1.0
# ROUGE-2: 0.0
# ROUGE-L: 1.0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 18 ---
# Full Article:
#  យោងតាមលោក Rasvinder Singh នាយកប្រតិបត្តិនៃក្រុមហ៊ុនបង្កើតកម្មវីធីកីឡា ដែលជាអ្នករៀបចំព្រឹត្តិការណ៍ D2D Mixed 5s ដ៏ធំបំផុតមួយរបស់សិង្ហបុរីបានឱ្យដឹងថា មានក្រុមចំនួន ៦ ហើយ ដែលក្រុមនីមួយៗមានបុរស និងស្ត្រី បានចុះឈ្មោះសម្រាប់ការប្រកួតហ្វូតសាលចម្រុះភេទនេះ។ ក្នុង​ចំណោមក្រុមទាំង៦នោះ មានសមាសភាព​កីឡាករ​ ៤០​នាក់​ និង ២៥​នាក់​ជា​ស្ត្រី។ លោក Rasvinder បានប្រាប់កាសែត CNA Women ថា ការបង្កើតកម្មវីធីកីឡាដ៏ថ្មីសន្លាងនេះឡើង ក្នុងគោលបំណងលើកស្ទួយដល់សមភាពយេនឌ័រ និងការពារកីឡាការិនី។ យ៉ាងណាក៏ដោយ នាយកប្រតិបត្តិរូបនេះ បង្ហាញការសោកស្តាយ ដ្បិតការប្រកួតកីឡាបាល់ទាត់ក្នុងសាលចម្រុះភេទនេះ គ្មានវត្តមានអាជ្ញាកណ្តាលជាស្ត្រីចូលរួម។ «យើងមិនដឹងអំពីអាជ្ញាកណ្តាលស្ត្រីណាម្នាក់នៅខាងក្រៅសហព័ន្ធកីឡាបាល់ទាត់សិង្ហបុរីទេ។ ដូច្នេះយើងមិនអាចរកអាជ្ញាកណ្តាលស្ត្រីបាន និងត្រូវប្រើអាជ្ញាកណ្តាលបុរសសុទ្ធតែម្តង ក្នុងការប្រកួតរយៈពេល៣ខែ។ លោក Rasvinder បន្ថែម។ លោក Rasvinder សង្ឃឹមដែរថា លីគបាល់ទាត់ក្នុងសាលថ្មីនេះ នឹងផ្តល់ឱកាសដល់កីឡាករ កីឡាការិនី ប្រកួតក្នុងបរិយាកាសមួយដែលមិនសូវមានភាពតានតឹង។ ក្នុងន័យនេះ គឺចង់សង្កត់ធ្ងន់លើការប្រកួតបាល់ទាត់ ដែលបង្ហាញភាពរីករាយជាមួយសមាជិកក្រុមដែលមានភេទផ្ទុយគ្នា ដោយសមាជិកក្រុមខ្លះអាចជាដៃគូស្នេហា ឬមិត្តភក្តិរបស់ពួកគេ។ ការប្រកួតនេះ នឹងមិនផ្តល់រង្វាន់ជាសាច់ប្រាក់សម្រាប់ក្រុមណាមួយឡើយ៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  ជាលើកដំបូងក្នុងការប្រកួតកីឡាបាល់ទាត់ហ្វូតសាលក្នុងប្រទេសសិង្ហបុរី ដែលបញ្ចូលគ្នារវាងបុរស និងនារីតែមួយ (D2D Mixed 5s) ជាផ្លូវការ ដែលនឹងប្រព្រឹត្តទៅចាប់ពីថ្ងៃទី២៦ ខែតុលា ដល់ថ្ងៃទី១៨ ខែមករា ឆ្នាំ២០២៤។ សិង្ហបុរី បង្កើតកម្មវិធីដ៏ភ្ញាក់ផ្អើលនេះឡើង ក្នុងគោលបំណង «ការពារកីឡាករនារី»។
#
# Predicted Summary:
#  សហព័ន្ធកីឡាបាល់ទាត់សិង្ហបុរី (D2D Mixed 5s) បានបង្កើតកម្មវីធីកីឡាដ៏ថ្មីសន្លាងមួយសម្រាប់សិង្ហបុរី ដើម្បីលើកស្ទួយសមភាពយេនឌ័រ និងការពារកីឡាការិនី។
# ROUGE-1: 1.0
# ROUGE-2: 1.0
# ROUGE-L: 1.0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 19 ---
# Full Article:
#  ទីភ្នាក់ងារសារព័ត៌មាន (KCNA) នៅថ្ងៃទី៨ ខែកុម្ភៈ បានចុះផ្សាយថា សភាប្រជាជនកូរ៉េខាងជើង បានសម្រេចលុបចោលកិច្ចសហប្រតិបត្តិការសេដ្ឋកិច្ចទាំងអស់ ជាមួយកូរ៉េខាងត្បូង ក៏ដូចជាលុបចោលច្បាប់គ្រប់គ្រងទំនាក់ទំនងសេដ្ឋកិច្ច និងច្បាប់ពិសេសស្តីពីប្រតិបត្តិការលើគម្រោងទេសចរណ៍នៅភ្នំ Kumgang។ តំបន់កម្សាន្ត Kumgang នៅភាគខាងត្បូងកូរ៉េខាងងជើងមានចម្ងាយប្រហែល ៥០គីឡូម៉ែត្រ ពីព្រំដែនធ្លាប់ជានិមិត្តរូបនៃកិច្ចសហប្រតិបត្តិការសេដ្ឋកិច្ចរវាងកូរ៉េទាំងពីរ និងបានទាក់ទាញភ្ញៀវទេសចរកូរ៉េខាងត្បូងជិត ២លាននាក់ នៅដើមទសវត្សរ៍ឆ្នាំ២០០០។ ប៉ុន្តែតំបន់ Kumgang ត្រូវបានបោះបង់តាំងពីទាហានកូរ៉េខាងជើង បានបាញ់សម្លាប់ភ្ញៀវទេសចរកូរ៉េខាងត្បូង ដែលបានវង្វេងចូលទៅក្នុងតំបន់យោធា ក្នុងឆ្នាំ២០០៨។ ក្រសួងបង្រួបបង្រួមកូរ៉េខាងត្បូង ដែលគ្រប់គ្រងរាល់ទំនាក់ទំនងជាមួយកូរ៉េខាងជើងបាននិយាយថា សកម្មភាពរបស់ទីក្រុងព្យុងយ៉ាង គឺគ្មានអ្វីគួរឱ្យភ្ញាក់ផ្អើលទេ ហើយថាទីក្រុង​សេអ៊ូល មិនទទួលស្គាល់ចលនាឯកតោភាគីបែបនេះទេ។ នៅក្នុងបទសម្ភាសន៍ជាមួយទូរទស្សន៍ KBS នៅថ្ងៃទី៧ ខែកុម្ភៈ ប្រធានាធិបតីកូរ៉េខាងត្បូង លោក យូន សុកយ៉ល បានបញ្ជាក់ថា លោកនៅតែមានឆន្ទៈសហការជាមួយទីក្រុងព្យុងយ៉ាង ហើយអាចនឹងធ្វើសន្និសីទកំពូល ជាមួយប្រធានាធិបតី គីម ជុងអ៊ុន ទៀតផង ដើម្បីផ្តល់ជំនួយសេដ្ឋកិច្ចដល់ប្រទេសនេះ។ ចាប់តាំងពីឡើងកាន់អំណាចមក លោក គីម ជុងអ៊ុន បានពន្លឿនកម្មវិធីរបស់ខ្លួន ក្នុងការអភិវឌ្ឍអាវុធនុយក្លេអ៊ែរ និងកាំជ្រួចផ្លោង ដែលបង្កភាពតានតឹងជាមួយអាម៉េរិក និងកូរ៉េខាងត្បូង។ នៅឆ្នាំ ២០២៣ ប្រទេសកូរ៉េខាងជើង បានលុបចោលសន្ធិសញ្ញាយោធា ដែលបានចុះហត្ថលេខាជាមួយកូរ៉េខាងត្បូង ដើម្បីកាត់បន្ថយភាពតានតឹងនៅតាមព្រំដែនក្នុងឆ្នាំ២០១៨៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  សភាកូរ៉េខាងជើង បានបោះឆ្នោតលុបចោលកិច្ចព្រមព្រៀងទាំងអស់ ដែលបានចុះហត្ថលេខាជាមួយកូរ៉េខាងត្បូង ដើម្បីលើកតម្កើងកិច្ចសហប្រតិបត្តិការសេដ្ឋកិច្ច។ ការហែកចោលកិច្ចព្រមព្រៀងទាំងនោះ កើតមានស្របពេលភាពតានតឹងក្នុងតំបន់កំពុងឡើងកម្តៅ។
#
# Predicted Summary:
#  ប្រធានាធិបតីកូរ៉េខាងត្បូង លោក យូន សុកយ៉ល បានប្រកាសលុបចោលកិច្ចសហប្រតិបត្តិការសេដ្ឋកិច្ចទាំងអស់ ជាមួយកូរ៉េខាងត្បូង និងលុបចោលច្បាប់គ្រប់គ្រងទំនាក់ទំនងសេដ្ឋកិច្ច និងច្បាប់ពិសេសស្តីពីប្រតិបត្តិការលើគម្រោងទេសចរណ៍នៅភ្នំ Kumgang នៅភាគខាងត្បូងកូរ៉េខាងជើង។
# ROUGE-1: 0.0
# ROUGE-2: 0.0
# ROUGE-L: 0
# ----------------------------------------------------------------------------------------------------
#
# --- Article 20 ---
# Full Article:
#  ឥណ្ឌូណេស៊ី នឹងត្រូវតទល់ម្ចាស់ផ្ទះអូស្ត្រាលី ដែលធ្វើឡើងនៅកីឡដ្ឋាន Allianz ទីក្រុងស៊ីដនី ប្រទេសអូស្ត្រាលី នៅវេលាម៉ោង ៤ និង ១០នាទី (ម៉ោងនៅកម្ពុជា)។ Kluivert អតីតកីឡាករខ្សែប្រយុទ្ធជម្រើសជាតិហូឡង់ និង Barcelona បានចូលកាន់កាប់តំណែងជាគ្រូបង្វឹកក្រុមឥណ្ឌូណេស៊ី សម្រាប់បេសកកម្មប្រកួតប្រជែងវគ្គជម្រុះ ដើម្បីដណ្តើមកៅអីទៅកាន់ជុំផ្តាច់ព្រ័ត្រព្រឹត្តិការណ៍ World Cup 2026 នៅប្រទេសអាម៉េរិក កាណាដា និងម៉ិកស៊ិក។ ខណៈកំពុងប្រកួតប្រជែងវគ្គជម្រុះជុំទី៣ ទ្វីបអាស៊ី ឥណ្ឌូណេស៊ី សម្លឹងចង់បានកៅអី World Cup លើកដំបូង បើរាប់ចាប់តាំងពីឆ្នាំ ១៩៣៨ ខណៈជំនួបក្រៅទឹកដីទល់អូស្ត្រាលី គឺជាការប្រកួតនឹងផ្តល់ក្តីសង្ឃឹមខ្ពស់មួយ។ បន្ទាប់ពីការប្រមូលផ្តុំ ក្រោយពេលកីឡាករភាគច្រើនរបស់ជម្រើសជាតិឥណ្ឌូណេស៊ី ទើបតែធ្វើដំណើរមកពីក្លិបតាមតំបន់អឺរ៉ុប លោក Kluivert ក៏បានអះអាងថាទោះក្រុមគ្មានពេលហ្វឹកហាត់គ្រប់គ្រាន់ ប៉ុន្តែលោកបានបញ្ជៀបគំនិត និងយុទ្ធសាស្ត្រល្អៗទៅកាន់ក្រុមរួចរាល់ ដើម្បីបង្កើនទំនុកចិត្តសម្រាប់ក្រុមត្រៀមខ្លួនប្រកួតទល់អូស្ត្រាលី។ ឥណ្ឌូណេស៊ី រំពឹងដណ្តើមបានជ័យជម្នះលើកដំបូងលើអូស្ត្រាលី គិតចាប់តាំងពីឆ្នាំ ១៩៨១ មក។ អ្នកចាត់ការវ័យ ៤៨ឆ្នាំ បាននិយាយដូច្នេះថា៖«ការផ្លាស់ប្តូរគឺជារឿងដ៏លំបាកមួយនៅពេលនេះ ពិតណាស់ មានរឿងខ្លះដែលខ្ញុំមិនចង់ពន្យល់នៅទីនេះ ប៉ុន្តែវានឹងមានអ្វីមួយកើតឡើង រឿងខ្លះនឹងអាចផ្លាស់ប្តូរ​ តែគឺនៅក្នុងរង្វង់របស់យើងតែប៉ុណ្ណោះ។ ខ្ញុំគិតថាក្រុមរបស់ខ្ញុំពេលនេះ បានត្រៀមខ្លួនរួចរាល ពួកគេដឹងថាយើងកំពុងតែគិតអ្វីនៅថ្ងៃស្អែក ដូច្នេះយើងសម្លឹងទៅមុខដើម្បីប្រកួតប្រជែងក្នុងជំនួបមួយនេះ។»។ ក្រុមជម្រើសជាតិឥណ្ឌូណេស៊ី ក្រោមការដឹកនាំរបស់លោក Kluivert បច្ចុប្បន្ន ភាគច្រើនជាកីឡាករកូនកាត់ និងចូលសញ្ជាតិ ឥណ្ឌូណេស៊ី-ហូឡង់ ហើយលេងនៅលីគកម្រិតខ្ពស់ប្រចាំតំបន់អឺរ៉ុប។ កាលពីជំនួបជើងទីមួយ នៅទឹកដីឥណ្ឌូណេស៊ី ការប្រកួតរវាងក្រុមទាំងពីរបញ្ចប់ទៅត្រឹមលទ្ធផល ០-០ ក្រោយមកឥណ្ឌូណេស៊ី បានយកឈ្នះលើក្រុមខ្លាំងក្នុងពូល C ជាមួយគ្នាអារ៉ាប៊ីសាអូឌីត លទ្ធផល ២-០ ដែលកាលនោះ ក្រុមមិនស្ថិតក្រោមការដឹកនាំរបស់លោក Kluivert ឡើយ។ មកដល់ពេលនេះឥណ្ឌូណេស៊ី ជាក្រុមឈរនៅលេខ ៣ ប្រចាំពូល C ដោយរកបានចំនួន ៦ពិន្ទុ ពីការប្រកួត ៦លើក ខណៈការប្រកួតប្រជែងក្នុងពូលមានភាពប្រទាញប្រទង់គ្នាខ្លាំង រាប់ចាប់ពីអូស្ត្រាលី ដែលឈរលេខ ២ រកបានទើបតែ ៧ពិន្ទុ។ អារ៉ាប៊ីសាអូឌីត លេខ ៤, បារែន លេខ ៥ និងចិន នៅលេខ ៦ មានចំនួន ៦ពិន្ទុដូចគ្នា។ វគ្គជម្រុះជុំទី៣ World Cup តំបន់អាស៊ី ក្រុមមានចំណាត់ថ្នាក់កំពូលតារាងទាំង ២ នឹងឈ្នះកៅអីជុំផ្តាច់ព្រ័ត្រ World Cup ​2026 ស្វ័យប្រវត្តិ ខណៈក្រុមលេខ ៣ និង លេខ ៤ ត្រូវបន្តទៅប្រជែងកៅអីនៅវគ្គជម្រុះជុំទី៤ បន្តទៀត៕ អ្នកសរសេរអត្ថបទ សូមចុចត្រង់នេះដើម្បីអានថ្មីៗជាភាសាអង់គ្លេស (Cambodianess.com)
#
# Reference Summary:
#  លោក Patrick Kluivert បានសន្យានាំភាពភ្ញាក់ផ្អើលដល់ក្រុមអ្នកគាំទ្រឥណ្ឌូណេស៊ី នៅមុនពេលឥណ្ឌូណេស៊ី តទល់ក្រុមអូស្ត្រាលី វគ្គជម្រុះជុំទី៣ FIFA World Cup 2026 ទ្វីបអាស៊ី។ ការសន្យារបស់អ្នកចាត់ការសញ្ជាតិហូឡង់ ធ្វើឡើងបន្ទាប់ពីទើបមានការហ្វឹកហាត់ត្រឹមតែ ២ ឬ ៣ លើកប៉ុណ្ណោះ ចាប់តាំងពីចូលកាន់តំណែងកាលពីខែមករា។
#
# Predicted Summary:
#  ឥណ្ឌូណេស៊ី រំពឹងដណ្តើមកៅអី World Cup 2026 នៅប្រទេសអាម៉េរិក កាណាដា និងម៉ិកស៊ិក ដើម្បីដណ្តើមកៅអីទៅកាន់ជុំផ្តាច់ព្រ័ត្រព្រឹត្តិការណ៍ World Cup 2026 នៅប្រទេសអាម៉េរិក កាណាដា និងម៉ិកស៊ិក។
# ROUGE-1: 0.5
# ROUGE-2: 0.4
# ROUGE-L: 0.5
# ----------------------------------------------------------------------------------------------------

# %%
# Your Khmer text
text = "ប្រទេស​​ចិន​បានដើរ​តួនាទី​​ជា​មជ្ឈមណ្ឌល​​ផ្គត់ផ្គង់​ទំនិញ​កាន់​តែ​​​សំខាន់​សម្រាប់ប្រទេស​កម្ពុជា ដោយ​ក្នុង​ឆ្នាំ​២០២៥ កន្លង​មក​ទំនិញ​ដែល​ប្រទេស​ចិន​នាំចូលកម្ពុជា​ មាន​ទឹក​ប្រាក់​​ជាង ១៨​ ពាន់​លាន​ដុល្លារ កើន​ជាង ៣០​% ​បើ​ធៀប​នឹង​ឆ្នាំ​២០២៤។ ប្រាក់​ដែល​កម្ពុជា​​បញ្ចេញ​សម្រាប់នាំចូល​​​ទំនិញ​ពី​ប្រទេសចិន​បាន​គ្រប​ដណ្តប់​លើស ៥០% នៃ​ចំនួន​ទឹក​ប្រាក់​សរុប​ដែល​កម្ពុជា​​បញ្ចេញ​សម្រាប់​​នាំ​ចូល​ទំនិញ​ពី​ប្រទេសដៃគូ​ពាណិជ្ជកម្ម​ទាំង​អស់​។​យោង​តាម​របាយការណ៍​របស់​​​អគ្គនាយក​ដ្ឋាន​គយ និង​រដ្ឋាករ​កម្ពុជា​(GDCE) ក្នុង​ឆ្នាំ ២០២៥ កម្ពុជា​បាន​បញ្ចេញ​ប្រាក់​សរុប​ ៣៣,៨៨ ពាន់​លាន​ដុល្លារ​ទៅ​លើ​ការ​នាំចូលទំនិញ​ពី​គ្រប់​ប្រទេស​ទាំង​អស់​លើ​ពិភពលោក ដោយ​កើន​ឡើង​ ១៨,៧%​ បើ​ធៀប​នឹង​ឆ្នាំ​២០២៤ ដែល​មាន ២៨,៥៤ ពាន់​លាន​ដុល្លារ​។ ក្នុងនោះ​​​ទំនិញ​នាំចូល​ពី​ប្រទេស​ចិន​មាន​ទឹក​ប្រាក់ ១៨,០៤ ពាន់លាន​ដុល្លារ កើន​ឡើង ៣៤,៣% ពី​ចំនួន ១៣,៤៣ ពាន់​លាន​ដុល្លារ​។ ទឹក​ប្រាក់ទិញ​ទំនិញ​ពី​ប្រទេស​ចិន​ស្មើ​នឹង ៥៣,២៥% នៃ​ចំនួន​ទឹក​ប្រាក់សរុប​ដែល​កម្ពុជា​បញ្ចេញ​សម្រាប់​​នាំ​ចូល​ទំនិញ​ពី​គ្រប់​ប្រទេស​ទាំង​អស់​។​"

# Tokenize and move to device
inputs = tokenizer(
    text,
    return_tensors="pt",
    truncation=True,
    max_length=512
).to(device)

# Generate summary
with torch.no_grad():
    summary_ids = model.generate(
        **inputs,
        max_length=200,
        num_beams=4,
        early_stopping=True
    )

# Decode the summary
summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
print("Predicted Summary:\n", summary)
# Out:
# Predicted Summary:
#  ទំនិញ នាំចូល ពី ប្រទេស ចិន បាន កើន ឡើង ១៨,៧% បើ ធៀប នឹង ឆ្នាំ ២០២៥ ដែល មាន ២៨,៥៤ ពាន់ លាន ដុល្លារ ។ នេះ បើ យោងតាម របាយការណ៍ របស់ អគ្គនាយក ដ្ឋាន គយ និង រដ្ឋាករ កម្ពុជា (GDCE) ។

# %%
# Your Khmer text
text = "ក្រុមអ្នកសង្កេតការណ៍អាស៊ាន (AOT) ចុះសង្កេតការណ៍ ផ្ទៀងផ្ទាត់ និងរាយការណ៍​អំពីស្ថានភាពនៅ​ភូមិកររបស់ប្រជាជន ក្នុងឃុំស្រអែម ស្រុកជាំក្សាន្ត ខេត្តព្រះវិហារ ព្រមទាំងទៅកាន់តំបន់ប្រាសាទព្រះវិហារ ដែលជាសម្បត្តិបេតិកភណ្ឌពិភពលោកដ៏មានតម្លៃបំផុតរបស់មនុស្សជាតិ។ការ​ចុះ​សង្កេតការណ៍​និង​ផ្ទៀង​ផ្ទាត់​នេះ គឺ​ជាការ​ចុះ​​លើក​ទី៦​ ទៅដល់​ទីតាំង​ដែល​រង​ការ​ខូច​ខាត​ពី​ការ​វាយប្រហារ​របស់​យោធាថៃ នៅ​ក្នុង​ខែ​មករា​នេះ ក្រោយ​ពេល​ប្រទេស​ទាំង​ពីរ បាន​ឈាន​ដល់​បទ​ឈប់​បាញ់​នៅថ្ងៃទី២៧ ខែធ្នូ ឆ្នាំ២០២៥។លោកស្រី ម៉ាលី សុជាតា អ្នក​នាំពាក្យ​ក្រសួង​ការពារជាតិ ថ្លែង​ថា កម្ពុជាតែងតែគោរព និងអនុវត្តយ៉ាងខ្ជាប់ខ្ជួននូវបទឈប់បាញ់​និង​សេចក្តីថ្លែងការណ៍រួមស្តីពីកិច្ចព្រមព្រៀងសន្តិភាពរវាងកម្ពុជានិងថៃ ព្រមទាំងកិច្ចព្រមព្រៀងពាក់ព័ន្ធដ៏ទៃទៀត។"
# Tokenize and move to device
inputs = tokenizer(
    text,
    return_tensors="pt",
    truncation=True,
    max_length=512
).to(device)

# Generate summary
with torch.no_grad():
    summary_ids = model.generate(
        **inputs,
        max_length=200,
        num_beams=4,
        early_stopping=True
    )

# Decode the summary
summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
print("Predicted Summary:\n", summary)
# Out:
# Predicted Summary:
#  លោកស្រី ម៉ាលី សុជាតា អ្នកសង្កេតការណ៍អាស៊ាន (AOT) ចុះ សង្កេតការណ៍ ផ្ទៀងផ្ទាត់ និងរាយការណ៍អំពីស្ថានភាពនៅ ភូមិកររបស់ប្រជាជន ក្នុងឃុំស្រអែម ស្រុកជាំក្សាន្ត ខេត្តព្រះវិហារ ដែល រង ការ ខូច ខាត ពី ការ វាយប្រហារ របស់ យោធាថៃ នៅថ្ងៃទី២៧ ខែធ្នូ ឆ្នាំ២០២៥។
